# %%
import numpy as np
import math


def rotate_points_about_origin(points, angle):
    """
    Rotates each point in 'points' about the origin by 'angle' radians in-place.
    """
    rotation_matrix = np.array([
        [math.cos(angle), -math.sin(angle)],
        [math.sin(angle),  math.cos(angle)]
    ])
    # Apply rotation in-place
    for i in range(len(points)):
        points[i] = rotation_matrix @ points[i]

def generate_noisy_three_edges_shared_origin_with_rotation(n, k, noise_std=0.01, seed=None):
    """
    Generates a shape consisting of three edges of lengths 2, 3, and 4,
    all emanating from a shared origin (0, 0). Each edge is discretized
    into 'n' points. Rotates and adds Gaussian noise 'k' times, returning
    a list of (points, simplices) pairs.

    :param n: Number of points on each edge, including the origin. Hence each edge 
              will have 'n' total points, with the origin being common to all edges.
    :param k: Number of rotated/noisy versions to generate.
    :param noise_std: Standard deviation of the added Gaussian noise (zero-mean).
    :param seed: Seed for the random number generator.
    :return: A list of length 'k', where each entry is (points, simplices).
    """

    if seed is not None:
        np.random.seed(seed)

    # Edges: lengths = [2, 3, 4]
    edge_lengths = [2.0, 3.0, 4.0]

    # Generate 3 random angles in [0, 2π)
    edge_angles = np.random.uniform(0, 2*math.pi, size=3)

    # Build base points
    base_points = []
    # Origin
    base_points.append([0.0, 0.0])

    # For each edge of length L, generate (n - 1) additional points
    # from origin to distance L, in direction of 'theta'
    for length, theta in zip(edge_lengths, edge_angles):
        for j in range(1, n):
            # fraction goes from 1/(n-1) up to (n-1)/(n-1) = 1
            fraction = j / (n - 1)
            t = length * fraction
            x = t * math.cos(theta)
            y = t * math.sin(theta)
            base_points.append([x, y])

    base_points = np.array(base_points, dtype=float)

    # Build simplices
    num_vertices = 1 + 3 * (n - 1)  # 1 (origin) + 3 edges * (n-1) new points
    simplices_template = []

    # Add 0-simplices (vertices)
    for i in range(num_vertices):
        simplices_template.append([i])

    # For each of the 3 edges, add 1-simplices (edges) from origin -> first point
    # and then consecutive points along that edge.
    for edge_i in range(3):
        start = 1 + edge_i * (n - 1)
        # connect origin -> first point on this edge
        simplices_template.append([0, start])
        # connect consecutive points
        for v in range(start, start + (n - 2)):
            simplices_template.append([v, v + 1])

    # Make a copy of the base points (before applying rotation/noise)
    current_points = base_points.copy()

    # Generate k rotated/noisy versions
    results = []
    for _ in range(k):
        # Random rotation angle
        angle = np.random.uniform(0, 2*math.pi)
        rotate_points_about_origin(current_points, angle)

        # Add Gaussian noise except for the origin
        noise = np.random.normal(0.0, noise_std, current_points.shape)
        noise[0, :] = 0.0  # origin stays fixed
        current_points += noise

        # Make copies for the result
        points_copy = current_points.copy()
        simplices_copy = [s[:] for s in simplices_template]

        results.append((points_copy, simplices_copy))

    return results



import matplotlib.pyplot as plt

def plot_simplicial_complexes(results):
    """
    Plots each simplicial complex in the results list on its own figure,
    with fixed axis limits (-5 to 5) for both x and y axes.

    :param results: A list of (points, simplices) tuples.
    """
    for i, (points, simp_comp) in enumerate(results):
        fig, ax = plt.subplots(figsize=(6, 6))
        
        # Plot the vertices
        ax.scatter(points[:, 0], points[:, 1], color='black', s=1)
        
        # Plot the edges (1-simplices)
        for simplex in simp_comp:
            simplex_points = points[simplex, :]
            if len(simplex) > 1:
                ax.plot(simplex_points[:, 0], simplex_points[:, 1], 'k-')
        
        # Fix the axis limits so every plot shows the region from -5 to 5
        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.set_aspect('equal')

        plt.show()

# %% [markdown]
# ## Randomly rotated samples

# %%
import My_ECT as detect
# Generate a list with exactly 1 entry, then unpack the first entry
results = generate_noisy_three_edges_shared_origin_with_rotation(100, 1, noise_std=0.01, seed=1)
(data1, simplex1) = results[0]

results2 = generate_noisy_three_edges_shared_origin_with_rotation(100, 1, noise_std=0.01, seed=2)
(data2, simplex2) = results2[0]
plot_simplicial_complexes([(data1, simplex1), (data2, simplex2)])
ect_image1 = detect.EctImg(simplex1, data1, k=1000, xinterval=(-5., 5.), xpoints=5000, yinterval=(0., 6), ypoints=6, factor=3)
ect_image2 = detect.EctImg(simplex2, data2, k=1000, xinterval=(-5., 5.), xpoints=5000, yinterval=(0., 6), ypoints=6, factor=3)
ect_image1.plot()
ect_image2.plot()

# %%
import numpy as np
import matplotlib.pyplot as plt

curve0 = detect.sect_2d(simplex1, data1, k=1000,
                                  interval=(-5.,5.), points=10000,
                                  mode='mean')
curve1 = detect.sect_2d(simplex2, data2, k=1000,
                                  interval=(-5.,5.), points=10000,
                                  mode='mean')

# 2) Reconstruct threshold axis
t0, t1 = -5.0, 5.0
t = np.linspace(t0, t1, curve0.shape[0])

# 3) Separate plots
# Class 0
plt.figure(figsize=(6, 4))
plt.plot(t, curve0)
plt.xlabel('Threshold $t$')
plt.ylabel('DETECT (mean Euler)')
plt.title(f'DETECT Curve for Simplicial Complex 1')
plt.tight_layout()
plt.show()

# Class 1
plt.figure(figsize=(6, 4))
plt.plot(t, curve1)
plt.xlabel('Threshold $t$')
plt.ylabel('DETECT (mean Euler)')
plt.title(f'DETECT Curve for Simplicial Complex 2')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### mdscale

# %%
shapes_class1 = generate_noisy_three_edges_shared_origin_with_rotation(n=100, k=20, noise_std=0.02, seed=1)
shapes_class2 = generate_noisy_three_edges_shared_origin_with_rotation(n=100, k=20, noise_std=0.02, seed=2)
all_shapes = shapes_class1 + shapes_class2  # total 40 shapes

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
from scipy.spatial.distance import cdist
from sklearn.manifold import MDS as mdscale
import matplotlib.pyplot as plt
import My_ECT as detect

def wasserstein_distance(empirical1, empirical2, p=2, delta_x=1.0):
    cost_matrix = cdist(empirical1, empirical2, metric='minkowski', p=p) * (delta_x ** (1.0 / p))
    row_ind, col_ind = linear_sum_assignment(cost_matrix)
    avg_cost_p = np.mean(cost_matrix[row_ind, col_ind] ** p)
    return avg_cost_p ** (1.0 / p)

def compute_distance_matrix(measures, p=2, delta_x=1.0):
    n = len(measures)
    D = np.zeros((n, n))
    for i in range(n):
        for j in range(i, n):
            d = wasserstein_distance(measures[i], measures[j], p=p, delta_x=delta_x)
            D[i, j] = D[j, i] = d
    return D

random_ect_list = []  # We'll store each shape's Random ECT (k x N) as an element in this list

k_val = 1000      # same value you used for detect.RandomEct_2d
num_points = 3000 # same value you used for detect.RandomEct_2d

for i, (points, simp_comp) in enumerate(all_shapes):
    # The random ECT is a (k_val x num_points) array
    random_ect = detect.RandomEct_2d(simp_comp, points, k=k_val, interval=(-5., 1.), points=num_points)
    random_ect = np.array(random_ect)  # shape = (1000, 3000)
    random_ect_list.append(random_ect)
delta_x = 6.0 / (num_points - 1)  
distance_matrix = compute_distance_matrix(random_ect_list, p=2, delta_x=delta_x)

# ----- HERE: metric MDS (mdscale) directly on distances -----
mds = mdscale(
    n_components=2,
    dissimilarity='precomputed',
    random_state=42,
    metric=True         # True for metric MDS (classical)
)
mds_coords = mds.fit_transform(distance_matrix)  # shape = (n_shapes, 2)

# ----- Plot the 2D embedding -----
labels = np.array([0]*20 + [1]*20)  # adjust if you have different class sizes
colors = plt.cm.viridis(np.linspace(0, 1, 2))
class_color_map = {0: colors[0], 1: colors[1]}
class_labels = {0: 'Class 1', 1: 'Class 2'}

plt.figure(figsize=(5,5))
font_props = {'family': 'Times New Roman', 'size': 12}

for cls, col in class_color_map.items():
    idx = np.where(labels == cls)[0]
    x, y = mds_coords[idx].T
    plt.scatter(x, y, label=class_labels[cls], color=col, marker='o')


# plt.title('MDS on SampEuler', fontdict=font_props)
plt.legend(prop=font_props)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.title('MDS on SampEuler', fontdict=font_props)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import MDS as mdscale

# — assume shapes_class1, shapes_class2, detect, generate… are already defined above —

labels = np.array([0]*20 + [1]*20)
all_shapes = shapes_class1 + shapes_class2

# 1) Compute your three feature matrices
ect_result, detect_result, image_result = [], [], []
for i, (points, simp_comp) in enumerate(all_shapes):
    # ECT curve
    ect_curve = detect.ect_2d(simp_comp, points, k=1000,
                              interval=(-5.,1.), points=3000)
    ect_result.append(np.array(ect_curve).flatten())

    # DETECT curve
    detect_curve = detect.sect_2d(simp_comp, points, k=1000,
                                  interval=(-5.,5.), points=10000,
                                  mode='mean')
    detect_result.append(detect_curve)

    # Image‐based ECT
    img = detect.EctImg(simp_comp, points, k=1000,
                        xinterval=(-5.,1.), xpoints=3000,
                        yinterval=(0.,4), ypoints=4, factor=1)
    image_result.append(img.compute(simp_comp, points,
                                    k=1000,
                                    xinterval=(-5.,1.),
                                    xpoints=3000,
                                    yinterval=(0.,4),
                                    ypoints=4,
                                    factor=1).flatten())

ect_for_mds     = np.vstack(ect_result)
detect_for_mds  = np.vstack(detect_result)
image_for_mds   = np.vstack(image_result)

# 2) Utility: compute L2 distance matrix
def compute_l2_distance_matrix(X):
    sum_sq = np.sum(X**2, axis=1, keepdims=True)
    dot = X @ X.T
    sq_dists = sum_sq + sum_sq.T - 2*dot
    return np.sqrt(np.maximum(sq_dists, 0.0))

# 3) A plotting helper using MDS (“mdscale”)
def mds_plot(features, labels, title_prefix):
    # 3a) distance matrix
    dist_matrix = compute_l2_distance_matrix(features)

    # 3b) classical MDS
    mds = mdscale(
        n_components=2,
        dissimilarity='precomputed',
        metric=True,
        random_state=42
    )
    coords = mds.fit_transform(dist_matrix)  # shape (n_samples, 2)

    # 3c) scatter plot
    colors = plt.cm.viridis(np.linspace(0, 1, 2))
    cmap = {0: colors[0], 1: colors[1]}
    labels_map = {0: 'Class 1', 1: 'Class 2'}

    plt.figure(figsize=(5,5))
    fp = {'family': 'Times New Roman', 'size': 12}

    for cls in [0,1]:
        idx = np.where(labels==cls)[0]
        x, y = coords[idx].T
        plt.scatter(x, y, label=labels_map[cls],
                    color=cmap[cls], marker='o')


    plt.legend(prop=fp)
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
    plt.title(f'MDS on {title_prefix}', fontdict=fp)
    plt.show()

# 4) Run MDS‐based embedding & plot for each feature set
mds_plot(ect_for_mds,    labels, "ECT Features")
mds_plot(detect_for_mds, labels, "DETECT Features")
mds_plot(image_for_mds,  labels, "SampEuler Vectorization Features")

# %% [markdown]
# ## aligned shapes

# %%
import numpy as np
import math

def generate_noisy_three_edges_shared_origin_no_rotation(n, k, noise_std=0.01, seed=None):
    """
    Generates a shape consisting of three edges of lengths 2, 3, and 4,
    all emanating from a shared origin (0, 0). Each edge is discretized
    into 'n' points. Adds Gaussian noise (without any rotation) k times,
    returning a list of (points, simplices) pairs.

    :param n: Number of points on each edge, including the origin. Hence each edge 
              will have 'n' total points, with the origin being common to all edges.
    :param k: Number of noisy versions to generate.
    :param noise_std: Standard deviation of the added Gaussian noise (zero-mean).
    :param seed: Seed for the random number generator.
    :return: A list of length 'k', where each entry is (points, simplices).
    """
    if seed is not None:
        np.random.seed(seed)

    # Edge lengths
    edge_lengths = [2.0, 3.0, 4.0]

    # Generate 3 random angles in [0, 2π)
    edge_angles = np.random.uniform(0, 2 * math.pi, size=3)

    # Build base points
    base_points = []
    base_points.append([0.0, 0.0])  # origin

    # For each edge, generate (n - 1) additional points from the origin to the edge length in a specific direction.
    for length, theta in zip(edge_lengths, edge_angles):
        for j in range(1, n):
            fraction = j / (n - 1)
            t = length * fraction
            x = t * math.cos(theta)
            y = t * math.sin(theta)
            base_points.append([x, y])

    base_points = np.array(base_points, dtype=float)

    # Build simplices
    num_vertices = 1 + 3 * (n - 1)  # 1 (origin) + 3 edges * (n-1) new points
    simplices_template = []

    # 0-simplices (vertices)
    for i in range(num_vertices):
        simplices_template.append([i])

    # 1-simplices (edges): for each edge, connect origin -> first point and consecutive points.
    for edge_i in range(3):
        start = 1 + edge_i * (n - 1)
        simplices_template.append([0, start])  # edge from origin to first point on the edge
        for v in range(start, start + (n - 2)):
            simplices_template.append([v, v + 1])

    results = []
    for _ in range(k):
        # Start with an unrotated copy of the base points.
        current_points = base_points.copy()

        # Add Gaussian noise, ensuring the origin remains fixed.
        noise = np.random.normal(0.0, noise_std, current_points.shape)
        noise[0, :] = 0.0  # fix the origin (first point)
        current_points += noise

        # Append the noisy points with a copy of the simplices template
        points_copy = current_points.copy()
        simplices_copy = [s[:] for s in simplices_template]
        results.append((points_copy, simplices_copy))

    return results

# For plotting the resulting complexes using matplotlib:
import matplotlib.pyplot as plt

def plot_simplicial_complexes(results):
    """
    Plots each simplicial complex in the results list on its own figure,
    with fixed axis limits (-5 to 5) for both x and y axes.

    :param results: A list of (points, simplices) tuples.
    """
    for i, (points, simp_comp) in enumerate(results):
        fig, ax = plt.subplots(figsize=(6, 6))
        
        # Plot the vertices
        ax.scatter(points[:, 0], points[:, 1], color='black', s=1)
        
        # Plot the edges (1-simplices)
        for simplex in simp_comp:
            simplex_points = points[simplex, :]
            if len(simplex) > 1:
                ax.plot(simplex_points[:, 0], simplex_points[:, 1], 'k-')
        
        # Fix the axis limits so every plot shows the region from -5 to 5
        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.set_aspect('equal')

        ax.set_title(f"Simplicial Complex {(i + 1)%20}")
        ax.set_xlabel("x")
        ax.set_ylabel("y")
        plt.show()

# %% [markdown]
# ### mdscale

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linear_sum_assignment
from scipy.spatial.distance import cdist
from sklearn.manifold import MDS as mdscale

# -----------------------------------------------------------------------------
# 1) Wasserstein distance & MDS on Random ECT
# -----------------------------------------------------------------------------

def wasserstein_distance(empirical1, empirical2, p=2, delta_x=1.0):
    cost_matrix = cdist(empirical1, empirical2, metric='minkowski', p=p) \
                  * (delta_x ** (1.0 / p))
    row_ind, col_ind = linear_sum_assignment(cost_matrix)
    avg_cost_p = np.mean(cost_matrix[row_ind, col_ind] ** p)
    return avg_cost_p ** (1.0 / p)

def compute_distance_matrix(measures, p=2, delta_x=1.0):
    n = len(measures)
    D = np.zeros((n, n))
    for i in range(n):
        for j in range(i, n):
            d = wasserstein_distance(measures[i], measures[j],
                                     p=p, delta_x=delta_x)
            D[i, j] = D[j, i] = d
    return D

# -- generate your data as before --
shapes_class1 = generate_noisy_three_edges_shared_origin_no_rotation(
    n=100, k=20, noise_std=0.005, seed=1)
shapes_class2 = generate_noisy_three_edges_shared_origin_no_rotation(
    n=100, k=20, noise_std=0.005, seed=2)
all_shapes = shapes_class1 + shapes_class2

# compute list of Random ECT arrays
random_ect_list = []
k_val, num_points = 1000, 3000
for points, simp_comp in all_shapes:
    re = detect.RandomEct_2d(simp_comp, points,
                             k=k_val,
                             interval=(-5.,1.),
                             points=num_points)
    random_ect_list.append(np.array(re))

# pairwise Wasserstein distances
delta_x = 6.0 / (num_points - 1)
W = compute_distance_matrix(random_ect_list,
                            p=2,
                            delta_x=delta_x)

# classical MDS on Wasserstein distances
mds_w = mdscale(
    n_components=2,
    dissimilarity='precomputed',
    metric=True,
    random_state=42
)
coords_w = mds_w.fit_transform(W)

# plot Random ECT embedding
labels = np.array([0]*20 + [1]*20)
colors = plt.cm.viridis(np.linspace(0,1,2))
cmap = {0: colors[0], 1: colors[1]}
lbls = {0:'Class 1', 1:'Class 2'}

plt.figure(figsize=(5,5))
fp = {'family':'Times New Roman','size':12}
for cls in [0,1]:
    idx = np.where(labels==cls)[0]
    x,y = coords_w[idx].T
    plt.scatter(x, y, label=lbls[cls], color=cmap[cls], marker='o')
plt.xticks([])
plt.yticks([])
plt.legend(prop=fp)
plt.tight_layout()
plt.title('MDS on SampEuler', fontdict=fp)
plt.show()

# -----------------------------------------------------------------------------
# 2) L2‐features & MDS on DETECT / ECT‐2d / Image‐ECT
# -----------------------------------------------------------------------------

# collect features
ect_res, detect_res, img_res = [], [], []
for points, simp_comp in all_shapes:
    # ECT curve
    ec = detect.ect_2d(simp_comp, points,
                      k=1000, interval=(-5.,1.), points=3000)
    ect_res.append(np.array(ec).flatten())

    # DETECT curve
    dc = detect.sect_2d(simp_comp, points,
                       k=1000, interval=(-5.,5.),
                       points=10000, mode='mean')
    detect_res.append(dc)

    # Image-based ECT
    im = detect.EctImg(simp_comp, points,
                       k=1000,
                       xinterval=(-5.,1.), xpoints=3000,
                       yinterval=(0.,4), ypoints=4,
                       factor=1)
    img_res.append(im.compute(simp_comp, points,
                              k=1000,
                              xinterval=(-5.,1.),
                              xpoints=3000,
                              yinterval=(0.,4),
                              ypoints=4,
                              factor=1).flatten())

X_ect    = np.vstack(ect_res)
X_detect = np.vstack(detect_res)
X_image  = np.vstack(img_res)

def compute_l2_distance_matrix(X):
    ss = np.sum(X**2, axis=1, keepdims=True)
    DP = X @ X.T
    sq = ss + ss.T - 2*DP
    return np.sqrt(np.maximum(sq, 0.0))

def mds_plot(X, labels, title):
    D = compute_l2_distance_matrix(X)
    mds = mdscale(n_components=2,
                  dissimilarity='precomputed',
                  metric=True,
                  random_state=42)
    C = mds.fit_transform(D)

    plt.figure(figsize=(5,5))
    fp = {'family':'Times New Roman','size':12}
    for cls in [0,1]:
        idx = np.where(labels==cls)[0]
        x,y = C[idx].T
        plt.scatter(x, y, label=lbls[cls], color=cmap[cls], marker='o')
    plt.xticks([])
    plt.yticks([])
    plt.legend(prop=fp)
    plt.tight_layout()
    plt.title(f'MDS on {title}', fontdict=fp)
    plt.show()

# plot all three
mds_plot(X_ect,    labels, "ECT Features")
mds_plot(X_detect, labels, "DETECT Features")
mds_plot(X_image,  labels, "SampEuler Vectorization ECT Features")

# %% [markdown]
# ## plots for MPEG-7

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from scipy.ndimage import label

def filter_to_largest_cc(img_array):
    """
    Filters the binary image to keep only the largest connected component.
    This function first creates a boolean mask identifying white pixels (values > 0),
    then labels connected regions using an 8-connected neighborhood. It determines which 
    connected component is largest (by pixel count) and returns a new image where only 
    that component is retained as white (1), while all other pixels are set to 0.
    
    Parameters:
        img_array : np.array
            Input binary image array (with values 0 or 1, or >0 for white).
    
    Returns:
        np.array
            A binary image with only the largest connected white component.
    """
    # Create a boolean mask for white pixels.
    mask = img_array > 0
    # Label connected components using an 8-connected structure.
    labeled_array, num_features = label(mask, structure=np.ones((3, 3)))
    
    # If there are no white pixels (no connected component), return an array of zeros.
    if num_features == 0:
        return np.zeros_like(img_array)
    
    # Count the number of pixels in each connected component.
    component_sizes = np.bincount(labeled_array.ravel())
    
    # The background is labeled 0, so find the largest component among the non-background labels.
    if len(component_sizes) > 1:
        largest_component = np.argmax(component_sizes[1:]) + 1  # +1 to adjust for the background index
    else:
        return np.zeros_like(img_array)
    
    # Create a new image that retains only the largest connected component.
    filtered_img = (labeled_array == largest_component)
    return filtered_img.astype(img_array.dtype)

def pad_image_to_square(img_array, target_length):
    """
    Pads a binary image (values 0 or 1) to a square of size target_length x target_length.
    The image is padded with zeros (black pixels) so that the average coordinate of
    all white pixels (pixels with a value > 0) is centered in the new image.
    
    Parameters:
        img_array : np.array
            Input binary image.
        target_length : int
            The size of the square output image.
    
    Returns:
        np.array
            The padded square image.
    """
    # Get the original dimensions.
    orig_height, orig_width = img_array.shape[0:2]
    
    # Identify white pixels (values > 0)
    white_pixels = np.argwhere(img_array > 0)
    if white_pixels.size == 0:
        # If there are no white pixels, default to the center of the original image.
        centroid = np.array([orig_height / 2.0, orig_width / 2.0])
    else:
        # Compute the centroid of the white pixels.
        centroid = white_pixels.mean(axis=0)
    
    # Define the center of the target square.
    target_center = np.array([target_length / 2.0, target_length / 2.0])
    # Compute the offset needed to shift the white pixel centroid to the center.
    offset = np.round(target_center - centroid).astype(int)
    
    # Create a new square image of target_length filled with zeros (black).
    new_img = np.zeros((target_length, target_length), dtype=img_array.dtype)
    
    # Compute destination coordinates for pasting.
    paste_row = offset[0]
    paste_col = offset[1]
    dest_row_start = max(0, paste_row)
    dest_col_start = max(0, paste_col)
    dest_row_end = min(target_length, paste_row + orig_height)
    dest_col_end = min(target_length, paste_col + orig_width)
    
    # Calculate the source region from the original image that is to be copied.
    src_row_start = max(0, -paste_row)
    src_col_start = max(0, -paste_col)
    src_row_end = src_row_start + (dest_row_end - dest_row_start)
    src_col_end = src_col_start + (dest_col_end - dest_col_start)
    
    # Paste the computed region into the new padded image.
    new_img[dest_row_start:dest_row_end, dest_col_start:dest_col_end] = \
        img_array[src_row_start:src_row_end, src_col_start:src_col_end]
    
    return new_img

# --- Sample Plot Code Using the Filter Function ---

# Example: choose a particular image file in the current directory.
directory = "/Users/hyang/Desktop/original"
filename  = "crown-18.gif"

# 2) Build the full path
file_path = os.path.join(directory, filename)

# 3) Open with PIL, handling animated GIFs by grabbing the first frame
with Image.open(file_path) as img:
    try:
        img.seek(0)
    except EOFError:
        pass
    img_array = np.array(img)

# First, filter the image to keep only the largest connected component.
filtered_img = filter_to_largest_cc(img_array)

# For demonstration, determine a target length.
# In full processing, this might be computed as (max_dim + 10).
target_length = 1182

# Pad the filtered image.
padded_img = pad_image_to_square(filtered_img, target_length)

# Plot the padded image.
plt.figure(figsize=(6, 6))
plt.imshow(padded_img, cmap="gray", interpolation="nearest")
plt.axis("off")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from scipy.ndimage import label, binary_fill_holes

def filter_to_largest_cc(img_array):
    """
    Fills holes in the binary image, then filters to keep only the largest connected component.
    """
    # 1) Create a boolean mask for white pixels
    mask = img_array > 0

    # 2) Fill any holes inside the mask
    filled = binary_fill_holes(mask)

    # 3) Label connected components (8-connected)
    labeled_array, num_features = label(filled, structure=np.ones((3, 3)))

    # 4) If nothing found, return zeros
    if num_features == 0:
        return np.zeros_like(img_array)

    # 5) Find sizes of each component
    component_sizes = np.bincount(labeled_array.ravel())

    # 6) Identify largest non-background component
    if len(component_sizes) > 1:
        largest_cc = np.argmax(component_sizes[1:]) + 1
    else:
        return np.zeros_like(img_array)

    # 7) Return only the largest CC as a binary image
    filtered = (labeled_array == largest_cc)
    return filtered.astype(img_array.dtype)

def pad_image_to_square(img_array, target_length):
    """
    Pads the (filtered & hole-filled) binary image to a target_length×target_length square,
    centering on the centroid of the white pixels.
    """
    orig_h, orig_w = img_array.shape
    white_pixels = np.argwhere(img_array > 0)

    if white_pixels.size == 0:
        centroid = np.array([orig_h / 2.0, orig_w / 2.0])
    else:
        centroid = white_pixels.mean(axis=0)

    target_center = np.array([target_length / 2.0, target_length / 2.0])
    offset = np.round(target_center - centroid).astype(int)

    new_img = np.zeros((target_length, target_length), dtype=img_array.dtype)

    pr, pc = offset
    dr0 = max(0, pr)
    dc0 = max(0, pc)
    dr1 = min(target_length, pr + orig_h)
    dc1 = min(target_length, pc + orig_w)

    sr0 = max(0, -pr)
    sc0 = max(0, -pc)
    sr1 = sr0 + (dr1 - dr0)
    sc1 = sc0 + (dc1 - dc0)

    new_img[dr0:dr1, dc0:dc1] = img_array[sr0:sr1, sc0:sc1]
    return new_img

# --- Example Usage ---

directory     = "/Users/hyang/Desktop/original"
filename      = "crown-18.gif"
file_path     = os.path.join(directory, filename)

# Load first frame of GIF
with Image.open(file_path) as img:
    try:
        img.seek(0)
    except EOFError:
        pass
    img_array = np.array(img)

# 1) Fill holes & keep largest CC
filtered_img = filter_to_largest_cc(img_array)

# 2) Pad to square
target_length = 1182
padded_img    = pad_image_to_square(filtered_img, target_length)

# 3) Display
plt.figure(figsize=(6, 6))
plt.imshow(padded_img, cmap="gray", interpolation="nearest")
plt.axis("off")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from scipy.ndimage import label, binary_fill_holes

def filter_to_largest_cc(img_array):
    mask   = img_array > 0
    filled = binary_fill_holes(mask)
    labeled, num = label(filled, structure=np.ones((3,3)))
    if num == 0:
        return np.zeros_like(img_array)
    sizes = np.bincount(labeled.ravel())
    if len(sizes) <= 1:
        return np.zeros_like(img_array)
    largest = np.argmax(sizes[1:]) + 1
    return (labeled == largest).astype(img_array.dtype)

def pad_image_to_square(img_array, target_length):
    h, w = img_array.shape
    white = np.argwhere(img_array > 0)
    if white.size == 0:
        centroid = np.array([h/2.0, w/2.0])
    else:
        centroid = white.mean(axis=0)
    center = np.array([target_length/2.0, target_length/2.0])
    offset = np.round(center - centroid).astype(int)

    new_img = np.zeros((target_length, target_length), dtype=img_array.dtype)
    pr, pc = offset
    dr0, dc0 = max(0, pr), max(0, pc)
    dr1 = min(target_length, pr + h)
    dc1 = min(target_length, pc + w)
    sr0, sc0 = max(0, -pr), max(0, -pc)
    sr1 = sr0 + (dr1 - dr0)
    sc1 = sc0 + (dc1 - dc0)

    new_img[dr0:dr1, dc0:dc1] = img_array[sr0:sr1, sc0:sc1]
    return new_img

# --- Batch processing all GIFs in a directory ---

source_dir = "/Users/hyang/Desktop/original"
processed_dir = os.path.join(source_dir, "processed")
os.makedirs(processed_dir, exist_ok=True)

# Decide on your square size here (e.g. max dimension + padding)
# If you want it dynamic per-image, you could compute inside the loop.
target_length = 1182  

for fname in os.listdir(source_dir):
    if not fname.lower().endswith(".gif"):
        continue

    in_path  = os.path.join(source_dir, fname)
    out_path = os.path.join(processed_dir, fname)

    # Load first frame
    with Image.open(in_path) as img:
        try:
            img.seek(0)
        except EOFError:
            pass
        arr = np.array(img)

    # If it’s multi-channel, convert to grayscale
    if arr.ndim == 3:
        # Simple average; or use more sophisticated conversion if you like
        arr = arr.mean(axis=2).astype(arr.dtype)

    # Process
    filtered = filter_to_largest_cc(arr)
    padded  = pad_image_to_square(filtered, target_length)

    # Scale binary 0/1 up to 0/255 for saving
    save_arr = (padded * 255).astype(np.uint8)
    Image.fromarray(save_arr).save(out_path)

    print(f"Processed {fname} → {out_path}")

# (Optional) Display one example
plt.figure(figsize=(4,4))
plt.imshow(save_arr, cmap="gray", interpolation="nearest")
plt.axis("off")
plt.show()
# Out:
# Processed children-3.gif → /Users/hyang/Desktop/original/processed/children-3.gif
# Processed face-5.gif → /Users/hyang/Desktop/original/processed/face-5.gif
# Processed watch-9.gif → /Users/hyang/Desktop/original/processed/watch-9.gif
# Processed apple-5.gif → /Users/hyang/Desktop/original/processed/apple-5.gif
# Processed pencil-12.gif → /Users/hyang/Desktop/original/processed/pencil-12.gif
# Processed dog-16.gif → /Users/hyang/Desktop/original/processed/dog-16.gif
# Processed lmfish-1.gif → /Users/hyang/Desktop/original/processed/lmfish-1.gif
# Processed bat-10.gif → /Users/hyang/Desktop/original/processed/bat-10.gif
# Processed teddy-20.gif → /Users/hyang/Desktop/original/processed/teddy-20.gif
# Processed key-20.gif → /Users/hyang/Desktop/original/processed/key-20.gif
# Processed teddy-08.gif → /Users/hyang/Desktop/original/processed/teddy-08.gif
# Processed device6-9.gif → /Users/hyang/Desktop/original/processed/device6-9.gif
# Processed chicken-16.gif → /Users/hyang/Desktop/original/processed/chicken-16.gif
# Processed hat-6.gif → /Users/hyang/Desktop/original/processed/hat-6.gif
# Processed watch-16.gif → /Users/hyang/Desktop/original/processed/watch-16.gif
# Processed bell-3.gif → /Users/hyang/Desktop/original/processed/bell-3.gif
# Processed horse-3.gif → /Users/hyang/Desktop/original/processed/horse-3.gif
# Processed device8-6.gif → /Users/hyang/Desktop/original/processed/device8-6.gif
# Processed device9-16.gif → /Users/hyang/Desktop/original/processed/device9-16.gif
# Processed horseshoe-17.gif → /Users/hyang/Desktop/original/processed/horseshoe-17.gif
# Processed spoon-5.gif → /Users/hyang/Desktop/original/processed/spoon-5.gif
# Processed shoe-1.gif → /Users/hyang/Desktop/original/processed/shoe-1.gif
# Processed device7-13.gif → /Users/hyang/Desktop/original/processed/device7-13.gif
# Processed rat-09.gif → /Users/hyang/Desktop/original/processed/rat-09.gif
# Processed cattle-1.gif → /Users/hyang/Desktop/original/processed/cattle-1.gif
# Processed pocket-16.gif → /Users/hyang/Desktop/original/processed/pocket-16.gif
# Processed cellular_phone-1.gif → /Users/hyang/Desktop/original/processed/cellular_phone-1.gif
# Processed frog-17.gif → /Users/hyang/Desktop/original/processed/frog-17.gif
# Processed beetle-16.gif → /Users/hyang/Desktop/original/processed/beetle-16.gif
# Processed sea_snake-19.gif → /Users/hyang/Desktop/original/processed/sea_snake-19.gif
# Processed dog-4.gif → /Users/hyang/Desktop/original/processed/dog-4.gif
# Processed hammer-19.gif → /Users/hyang/Desktop/original/processed/hammer-19.gif
# Processed Bone-10.gif → /Users/hyang/Desktop/original/processed/Bone-10.gif
# Processed tree-14.gif → /Users/hyang/Desktop/original/processed/tree-14.gif
# Processed pocket-4.gif → /Users/hyang/Desktop/original/processed/pocket-4.gif
# Processed device5-16.gif → /Users/hyang/Desktop/original/processed/device5-16.gif
# Processed guitar-18.gif → /Users/hyang/Desktop/original/processed/guitar-18.gif
# Processed hat-13.gif → /Users/hyang/Desktop/original/processed/hat-13.gif
# Processed guitar-4.gif → /Users/hyang/Desktop/original/processed/guitar-4.gif
# Processed personal_car-13.gif → /Users/hyang/Desktop/original/processed/personal_car-13.gif
# Processed spring-4.gif → /Users/hyang/Desktop/original/processed/spring-4.gif
# Processed ray-5.gif → /Users/hyang/Desktop/original/processed/ray-5.gif
# Processed chicken-3.gif → /Users/hyang/Desktop/original/processed/chicken-3.gif
# Processed chicken-2.gif → /Users/hyang/Desktop/original/processed/chicken-2.gif
# Processed ray-4.gif → /Users/hyang/Desktop/original/processed/ray-4.gif
# Processed camel-1.gif → /Users/hyang/Desktop/original/processed/camel-1.gif
# Processed spring-5.gif → /Users/hyang/Desktop/original/processed/spring-5.gif
# Processed personal_car-12.gif → /Users/hyang/Desktop/original/processed/personal_car-12.gif
# Processed guitar-5.gif → /Users/hyang/Desktop/original/processed/guitar-5.gif
# Processed hat-12.gif → /Users/hyang/Desktop/original/processed/hat-12.gif
# Processed guitar-19.gif → /Users/hyang/Desktop/original/processed/guitar-19.gif
# Processed device5-17.gif → /Users/hyang/Desktop/original/processed/device5-17.gif
# Processed pocket-5.gif → /Users/hyang/Desktop/original/processed/pocket-5.gif
# Processed tree-15.gif → /Users/hyang/Desktop/original/processed/tree-15.gif
# Processed Bone-11.gif → /Users/hyang/Desktop/original/processed/Bone-11.gif
# Processed dog-5.gif → /Users/hyang/Desktop/original/processed/dog-5.gif
# Processed hammer-18.gif → /Users/hyang/Desktop/original/processed/hammer-18.gif
# Processed sea_snake-18.gif → /Users/hyang/Desktop/original/processed/sea_snake-18.gif
# Processed frog-16.gif → /Users/hyang/Desktop/original/processed/frog-16.gif
# Processed beetle-17.gif → /Users/hyang/Desktop/original/processed/beetle-17.gif
# Processed rat-08.gif → /Users/hyang/Desktop/original/processed/rat-08.gif
# Processed device7-12.gif → /Users/hyang/Desktop/original/processed/device7-12.gif
# Processed pocket-17.gif → /Users/hyang/Desktop/original/processed/pocket-17.gif
# Processed jar-20.gif → /Users/hyang/Desktop/original/processed/jar-20.gif
# Processed Comma-1.gif → /Users/hyang/Desktop/original/processed/Comma-1.gif
# Processed spoon-4.gif → /Users/hyang/Desktop/original/processed/spoon-4.gif
# Processed horseshoe-16.gif → /Users/hyang/Desktop/original/processed/horseshoe-16.gif
# Processed horse-2.gif → /Users/hyang/Desktop/original/processed/horse-2.gif
# Processed device9-17.gif → /Users/hyang/Desktop/original/processed/device9-17.gif
# Processed rat-20.gif → /Users/hyang/Desktop/original/processed/rat-20.gif
# Processed device8-7.gif → /Users/hyang/Desktop/original/processed/device8-7.gif
# Processed bell-2.gif → /Users/hyang/Desktop/original/processed/bell-2.gif
# Processed watch-17.gif → /Users/hyang/Desktop/original/processed/watch-17.gif
# Processed chicken-17.gif → /Users/hyang/Desktop/original/processed/chicken-17.gif
# Processed device6-8.gif → /Users/hyang/Desktop/original/processed/device6-8.gif
# Processed shoe-20.gif → /Users/hyang/Desktop/original/processed/shoe-20.gif
# Processed hat-7.gif → /Users/hyang/Desktop/original/processed/hat-7.gif
# Processed octopus-20.gif → /Users/hyang/Desktop/original/processed/octopus-20.gif
# Processed teddy-09.gif → /Users/hyang/Desktop/original/processed/teddy-09.gif
# Processed bat-11.gif → /Users/hyang/Desktop/original/processed/bat-11.gif
# Processed dog-17.gif → /Users/hyang/Desktop/original/processed/dog-17.gif
# Processed pencil-13.gif → /Users/hyang/Desktop/original/processed/pencil-13.gif
# Processed apple-4.gif → /Users/hyang/Desktop/original/processed/apple-4.gif
# Processed watch-8.gif → /Users/hyang/Desktop/original/processed/watch-8.gif
# Processed children-2.gif → /Users/hyang/Desktop/original/processed/children-2.gif
# Processed face-4.gif → /Users/hyang/Desktop/original/processed/face-4.gif
# Processed apple-6.gif → /Users/hyang/Desktop/original/processed/apple-6.gif
# Processed device4-8.gif → /Users/hyang/Desktop/original/processed/device4-8.gif
# Processed face-6.gif → /Users/hyang/Desktop/original/processed/face-6.gif
# Processed lmfish-2.gif → /Users/hyang/Desktop/original/processed/lmfish-2.gif
# Processed pencil-11.gif → /Users/hyang/Desktop/original/processed/pencil-11.gif
# Processed dog-15.gif → /Users/hyang/Desktop/original/processed/dog-15.gif
# Processed bat-13.gif → /Users/hyang/Desktop/original/processed/bat-13.gif
# Processed hat-5.gif → /Users/hyang/Desktop/original/processed/hat-5.gif
# Processed chicken-15.gif → /Users/hyang/Desktop/original/processed/chicken-15.gif
# Processed camel-18.gif → /Users/hyang/Desktop/original/processed/camel-18.gif
# Processed watch-15.gif → /Users/hyang/Desktop/original/processed/watch-15.gif
# Processed device8-5.gif → /Users/hyang/Desktop/original/processed/device8-5.gif
# Processed device9-15.gif → /Users/hyang/Desktop/original/processed/device9-15.gif
# Processed crown-20.gif → /Users/hyang/Desktop/original/processed/crown-20.gif
# Processed device0-19.gif → /Users/hyang/Desktop/original/processed/device0-19.gif
# Processed cattle-2.gif → /Users/hyang/Desktop/original/processed/cattle-2.gif
# Processed pocket-15.gif → /Users/hyang/Desktop/original/processed/pocket-15.gif
# Processed device7-10.gif → /Users/hyang/Desktop/original/processed/device7-10.gif
# Processed horseshoe-14.gif → /Users/hyang/Desktop/original/processed/horseshoe-14.gif
# Processed spoon-6.gif → /Users/hyang/Desktop/original/processed/spoon-6.gif
# Processed Comma-3.gif → /Users/hyang/Desktop/original/processed/Comma-3.gif
# Processed shoe-2.gif → /Users/hyang/Desktop/original/processed/shoe-2.gif
# Processed brick-20.gif → /Users/hyang/Desktop/original/processed/brick-20.gif
# Processed beetle-15.gif → /Users/hyang/Desktop/original/processed/beetle-15.gif
# Processed frog-14.gif → /Users/hyang/Desktop/original/processed/frog-14.gif
# Processed cellular_phone-2.gif → /Users/hyang/Desktop/original/processed/cellular_phone-2.gif
# Processed Bone-13.gif → /Users/hyang/Desktop/original/processed/Bone-13.gif
# Processed brick-08.gif → /Users/hyang/Desktop/original/processed/brick-08.gif
# Processed dog-7.gif → /Users/hyang/Desktop/original/processed/dog-7.gif
# Processed tree-17.gif → /Users/hyang/Desktop/original/processed/tree-17.gif
# Processed device2-20.gif → /Users/hyang/Desktop/original/processed/device2-20.gif
# Processed device5-15.gif → /Users/hyang/Desktop/original/processed/device5-15.gif
# Processed fish-8.gif → /Users/hyang/Desktop/original/processed/fish-8.gif
# Processed pocket-7.gif → /Users/hyang/Desktop/original/processed/pocket-7.gif
# Processed Glas-19.gif → /Users/hyang/Desktop/original/processed/Glas-19.gif
# Processed hat-10.gif → /Users/hyang/Desktop/original/processed/hat-10.gif
# Processed personal_car-8.gif → /Users/hyang/Desktop/original/processed/personal_car-8.gif
# Processed guitar-7.gif → /Users/hyang/Desktop/original/processed/guitar-7.gif
# Processed bottle-20.gif → /Users/hyang/Desktop/original/processed/bottle-20.gif
# Processed personal_car-10.gif → /Users/hyang/Desktop/original/processed/personal_car-10.gif
# Processed bottle-08.gif → /Users/hyang/Desktop/original/processed/bottle-08.gif
# Processed spring-7.gif → /Users/hyang/Desktop/original/processed/spring-7.gif
# Processed camel-3.gif → /Users/hyang/Desktop/original/processed/camel-3.gif
# Processed fountain-20.gif → /Users/hyang/Desktop/original/processed/fountain-20.gif
# Processed ray-6.gif → /Users/hyang/Desktop/original/processed/ray-6.gif
# Processed fountain-08.gif → /Users/hyang/Desktop/original/processed/fountain-08.gif
# Processed fountain-09.gif → /Users/hyang/Desktop/original/processed/fountain-09.gif
# Processed chicken-1.gif → /Users/hyang/Desktop/original/processed/chicken-1.gif
# Processed ray-7.gif → /Users/hyang/Desktop/original/processed/ray-7.gif
# Processed spring-6.gif → /Users/hyang/Desktop/original/processed/spring-6.gif
# Processed bottle-09.gif → /Users/hyang/Desktop/original/processed/bottle-09.gif
# Processed personal_car-11.gif → /Users/hyang/Desktop/original/processed/personal_car-11.gif
# Processed camel-2.gif → /Users/hyang/Desktop/original/processed/camel-2.gif
# Processed guitar-6.gif → /Users/hyang/Desktop/original/processed/guitar-6.gif
# Processed personal_car-9.gif → /Users/hyang/Desktop/original/processed/personal_car-9.gif
# Processed hat-11.gif → /Users/hyang/Desktop/original/processed/hat-11.gif
# Processed Glas-18.gif → /Users/hyang/Desktop/original/processed/Glas-18.gif
# Processed pocket-6.gif → /Users/hyang/Desktop/original/processed/pocket-6.gif
# Processed device5-14.gif → /Users/hyang/Desktop/original/processed/device5-14.gif
# Processed fish-9.gif → /Users/hyang/Desktop/original/processed/fish-9.gif
# Processed tree-16.gif → /Users/hyang/Desktop/original/processed/tree-16.gif
# Processed brick-09.gif → /Users/hyang/Desktop/original/processed/brick-09.gif
# Processed dog-6.gif → /Users/hyang/Desktop/original/processed/dog-6.gif
# Processed Bone-12.gif → /Users/hyang/Desktop/original/processed/Bone-12.gif
# Processed beetle-14.gif → /Users/hyang/Desktop/original/processed/beetle-14.gif
# Processed cellular_phone-3.gif → /Users/hyang/Desktop/original/processed/cellular_phone-3.gif
# Processed frog-15.gif → /Users/hyang/Desktop/original/processed/frog-15.gif
# Processed shoe-3.gif → /Users/hyang/Desktop/original/processed/shoe-3.gif
# Processed Comma-2.gif → /Users/hyang/Desktop/original/processed/Comma-2.gif
# Processed spoon-7.gif → /Users/hyang/Desktop/original/processed/spoon-7.gif
# Processed horseshoe-15.gif → /Users/hyang/Desktop/original/processed/horseshoe-15.gif
# Processed pocket-14.gif → /Users/hyang/Desktop/original/processed/pocket-14.gif
# Processed cattle-3.gif → /Users/hyang/Desktop/original/processed/cattle-3.gif
# Processed device0-18.gif → /Users/hyang/Desktop/original/processed/device0-18.gif
# Processed device7-11.gif → /Users/hyang/Desktop/original/processed/device7-11.gif
# Processed device9-14.gif → /Users/hyang/Desktop/original/processed/device9-14.gif
# Processed bird-20.gif → /Users/hyang/Desktop/original/processed/bird-20.gif
# Processed device8-4.gif → /Users/hyang/Desktop/original/processed/device8-4.gif
# Processed horse-1.gif → /Users/hyang/Desktop/original/processed/horse-1.gif
# Processed bell-1.gif → /Users/hyang/Desktop/original/processed/bell-1.gif
# Processed watch-14.gif → /Users/hyang/Desktop/original/processed/watch-14.gif
# Processed camel-19.gif → /Users/hyang/Desktop/original/processed/camel-19.gif
# Processed Misk-20.gif → /Users/hyang/Desktop/original/processed/Misk-20.gif
# Processed hat-4.gif → /Users/hyang/Desktop/original/processed/hat-4.gif
# Processed chicken-14.gif → /Users/hyang/Desktop/original/processed/chicken-14.gif
# Processed deer-20.gif → /Users/hyang/Desktop/original/processed/deer-20.gif
# Processed bat-12.gif → /Users/hyang/Desktop/original/processed/bat-12.gif
# Processed lmfish-3.gif → /Users/hyang/Desktop/original/processed/lmfish-3.gif
# Processed dog-14.gif → /Users/hyang/Desktop/original/processed/dog-14.gif
# Processed pencil-10.gif → /Users/hyang/Desktop/original/processed/pencil-10.gif
# Processed face-7.gif → /Users/hyang/Desktop/original/processed/face-7.gif
# Processed children-1.gif → /Users/hyang/Desktop/original/processed/children-1.gif
# Processed device4-9.gif → /Users/hyang/Desktop/original/processed/device4-9.gif
# Processed apple-7.gif → /Users/hyang/Desktop/original/processed/apple-7.gif
# Processed pencil-14.gif → /Users/hyang/Desktop/original/processed/pencil-14.gif
# Processed dog-10.gif → /Users/hyang/Desktop/original/processed/dog-10.gif
# Processed lmfish-7.gif → /Users/hyang/Desktop/original/processed/lmfish-7.gif
# Processed apple-3.gif → /Users/hyang/Desktop/original/processed/apple-3.gif
# Processed children-5.gif → /Users/hyang/Desktop/original/processed/children-5.gif
# Processed face-3.gif → /Users/hyang/Desktop/original/processed/face-3.gif
# Processed deer-18.gif → /Users/hyang/Desktop/original/processed/deer-18.gif
# Processed bat-16.gif → /Users/hyang/Desktop/original/processed/bat-16.gif
# Processed deer-8.gif → /Users/hyang/Desktop/original/processed/deer-8.gif
# Processed Heart-8.gif → /Users/hyang/Desktop/original/processed/Heart-8.gif
# Processed Misk-18.gif → /Users/hyang/Desktop/original/processed/Misk-18.gif
# Processed watch-10.gif → /Users/hyang/Desktop/original/processed/watch-10.gif
# Processed bell-5.gif → /Users/hyang/Desktop/original/processed/bell-5.gif
# Processed chicken-10.gif → /Users/hyang/Desktop/original/processed/chicken-10.gif
# Processed device7-15.gif → /Users/hyang/Desktop/original/processed/device7-15.gif
# Processed pocket-10.gif → /Users/hyang/Desktop/original/processed/pocket-10.gif
# Processed cattle-7.gif → /Users/hyang/Desktop/original/processed/cattle-7.gif
# Processed horseshoe-11.gif → /Users/hyang/Desktop/original/processed/horseshoe-11.gif
# Processed spoon-3.gif → /Users/hyang/Desktop/original/processed/spoon-3.gif
# Processed crown-19.gif → /Users/hyang/Desktop/original/processed/crown-19.gif
# Processed Comma-6.gif → /Users/hyang/Desktop/original/processed/Comma-6.gif
# Processed shoe-7.gif → /Users/hyang/Desktop/original/processed/shoe-7.gif
# Processed bird-18.gif → /Users/hyang/Desktop/original/processed/bird-18.gif
# Processed device0-20.gif → /Users/hyang/Desktop/original/processed/device0-20.gif
# Processed horse-5.gif → /Users/hyang/Desktop/original/processed/horse-5.gif
# Processed device9-10.gif → /Users/hyang/Desktop/original/processed/device9-10.gif
# Processed brick-19.gif → /Users/hyang/Desktop/original/processed/brick-19.gif
# Processed Bone-16.gif → /Users/hyang/Desktop/original/processed/Bone-16.gif
# Processed dog-2.gif → /Users/hyang/Desktop/original/processed/dog-2.gif
# Processed frog-11.gif → /Users/hyang/Desktop/original/processed/frog-11.gif
# Processed cellular_phone-7.gif → /Users/hyang/Desktop/original/processed/cellular_phone-7.gif
# Processed device0-9.gif → /Users/hyang/Desktop/original/processed/device0-9.gif
# Processed beetle-10.gif → /Users/hyang/Desktop/original/processed/beetle-10.gif
# Processed device2-19.gif → /Users/hyang/Desktop/original/processed/device2-19.gif
# Processed device5-10.gif → /Users/hyang/Desktop/original/processed/device5-10.gif
# Processed pocket-2.gif → /Users/hyang/Desktop/original/processed/pocket-2.gif
# Processed tree-12.gif → /Users/hyang/Desktop/original/processed/tree-12.gif
# Processed Glas-20.gif → /Users/hyang/Desktop/original/processed/Glas-20.gif
# Processed bottle-19.gif → /Users/hyang/Desktop/original/processed/bottle-19.gif
# Processed camel-6.gif → /Users/hyang/Desktop/original/processed/camel-6.gif
# Processed personal_car-15.gif → /Users/hyang/Desktop/original/processed/personal_car-15.gif
# Processed spring-2.gif → /Users/hyang/Desktop/original/processed/spring-2.gif
# Processed hat-15.gif → /Users/hyang/Desktop/original/processed/hat-15.gif
# Processed guitar-2.gif → /Users/hyang/Desktop/original/processed/guitar-2.gif
# Processed chicken-5.gif → /Users/hyang/Desktop/original/processed/chicken-5.gif
# Processed fountain-19.gif → /Users/hyang/Desktop/original/processed/fountain-19.gif
# Processed ray-3.gif → /Users/hyang/Desktop/original/processed/ray-3.gif
# Processed ray-2.gif → /Users/hyang/Desktop/original/processed/ray-2.gif
# Processed fountain-18.gif → /Users/hyang/Desktop/original/processed/fountain-18.gif
# Processed chicken-4.gif → /Users/hyang/Desktop/original/processed/chicken-4.gif
# Processed guitar-3.gif → /Users/hyang/Desktop/original/processed/guitar-3.gif
# Processed hat-14.gif → /Users/hyang/Desktop/original/processed/hat-14.gif
# Processed camel-7.gif → /Users/hyang/Desktop/original/processed/camel-7.gif
# Processed spring-3.gif → /Users/hyang/Desktop/original/processed/spring-3.gif
# Processed personal_car-14.gif → /Users/hyang/Desktop/original/processed/personal_car-14.gif
# Processed bottle-18.gif → /Users/hyang/Desktop/original/processed/bottle-18.gif
# Processed tree-13.gif → /Users/hyang/Desktop/original/processed/tree-13.gif
# Processed pocket-3.gif → /Users/hyang/Desktop/original/processed/pocket-3.gif
# Processed device2-18.gif → /Users/hyang/Desktop/original/processed/device2-18.gif
# Processed device5-11.gif → /Users/hyang/Desktop/original/processed/device5-11.gif
# Processed device0-8.gif → /Users/hyang/Desktop/original/processed/device0-8.gif
# Processed cellular_phone-6.gif → /Users/hyang/Desktop/original/processed/cellular_phone-6.gif
# Processed frog-10.gif → /Users/hyang/Desktop/original/processed/frog-10.gif
# Processed beetle-11.gif → /Users/hyang/Desktop/original/processed/beetle-11.gif
# Processed dog-3.gif → /Users/hyang/Desktop/original/processed/dog-3.gif
# Processed brick-18.gif → /Users/hyang/Desktop/original/processed/brick-18.gif
# Processed Bone-17.gif → /Users/hyang/Desktop/original/processed/Bone-17.gif
# Processed horse-4.gif → /Users/hyang/Desktop/original/processed/horse-4.gif
# Processed device9-11.gif → /Users/hyang/Desktop/original/processed/device9-11.gif
# Processed device8-1.gif → /Users/hyang/Desktop/original/processed/device8-1.gif
# Processed shoe-6.gif → /Users/hyang/Desktop/original/processed/shoe-6.gif
# Processed crown-18.gif → /Users/hyang/Desktop/original/processed/crown-18.gif
# Processed Comma-7.gif → /Users/hyang/Desktop/original/processed/Comma-7.gif
# Processed spoon-2.gif → /Users/hyang/Desktop/original/processed/spoon-2.gif
# Processed horseshoe-10.gif → /Users/hyang/Desktop/original/processed/horseshoe-10.gif
# Processed bird-19.gif → /Users/hyang/Desktop/original/processed/bird-19.gif
# Processed device7-14.gif → /Users/hyang/Desktop/original/processed/device7-14.gif
# Processed cattle-6.gif → /Users/hyang/Desktop/original/processed/cattle-6.gif
# Processed pocket-11.gif → /Users/hyang/Desktop/original/processed/pocket-11.gif
# Processed chicken-11.gif → /Users/hyang/Desktop/original/processed/chicken-11.gif
# Processed hat-1.gif → /Users/hyang/Desktop/original/processed/hat-1.gif
# Processed bell-4.gif → /Users/hyang/Desktop/original/processed/bell-4.gif
# Processed watch-11.gif → /Users/hyang/Desktop/original/processed/watch-11.gif
# Processed Misk-19.gif → /Users/hyang/Desktop/original/processed/Misk-19.gif
# Processed camel-20.gif → /Users/hyang/Desktop/original/processed/camel-20.gif
# Processed Heart-9.gif → /Users/hyang/Desktop/original/processed/Heart-9.gif
# Processed bat-17.gif → /Users/hyang/Desktop/original/processed/bat-17.gif
# Processed deer-9.gif → /Users/hyang/Desktop/original/processed/deer-9.gif
# Processed deer-19.gif → /Users/hyang/Desktop/original/processed/deer-19.gif
# Processed children-4.gif → /Users/hyang/Desktop/original/processed/children-4.gif
# Processed face-2.gif → /Users/hyang/Desktop/original/processed/face-2.gif
# Processed apple-2.gif → /Users/hyang/Desktop/original/processed/apple-2.gif
# Processed dog-11.gif → /Users/hyang/Desktop/original/processed/dog-11.gif
# Processed pencil-15.gif → /Users/hyang/Desktop/original/processed/pencil-15.gif
# Processed lmfish-6.gif → /Users/hyang/Desktop/original/processed/lmfish-6.gif
# Processed lmfish-4.gif → /Users/hyang/Desktop/original/processed/lmfish-4.gif
# Processed pencil-17.gif → /Users/hyang/Desktop/original/processed/pencil-17.gif
# Processed dog-13.gif → /Users/hyang/Desktop/original/processed/dog-13.gif
# Processed children-6.gif → /Users/hyang/Desktop/original/processed/children-6.gif
# Processed teddy-19.gif → /Users/hyang/Desktop/original/processed/teddy-19.gif
# Processed bat-15.gif → /Users/hyang/Desktop/original/processed/bat-15.gif
# Processed key-19.gif → /Users/hyang/Desktop/original/processed/key-19.gif
# Processed watch-13.gif → /Users/hyang/Desktop/original/processed/watch-13.gif
# Processed bell-6.gif → /Users/hyang/Desktop/original/processed/bell-6.gif
# Processed octopus-18.gif → /Users/hyang/Desktop/original/processed/octopus-18.gif
# Processed shoe-18.gif → /Users/hyang/Desktop/original/processed/shoe-18.gif
# Processed hat-3.gif → /Users/hyang/Desktop/original/processed/hat-3.gif
# Processed elephant-9.gif → /Users/hyang/Desktop/original/processed/elephant-9.gif
# Processed chicken-13.gif → /Users/hyang/Desktop/original/processed/chicken-13.gif
# Processed rat-18.gif → /Users/hyang/Desktop/original/processed/rat-18.gif
# Processed horseshoe-12.gif → /Users/hyang/Desktop/original/processed/horseshoe-12.gif
# Processed shoe-4.gif → /Users/hyang/Desktop/original/processed/shoe-4.gif
# Processed Comma-5.gif → /Users/hyang/Desktop/original/processed/Comma-5.gif
# Processed pocket-13.gif → /Users/hyang/Desktop/original/processed/pocket-13.gif
# Processed cattle-4.gif → /Users/hyang/Desktop/original/processed/cattle-4.gif
# Processed device7-16.gif → /Users/hyang/Desktop/original/processed/device7-16.gif
# Processed device8-3.gif → /Users/hyang/Desktop/original/processed/device8-3.gif
# Processed device9-13.gif → /Users/hyang/Desktop/original/processed/device9-13.gif
# Processed horse-6.gif → /Users/hyang/Desktop/original/processed/horse-6.gif
# Processed jar-18.gif → /Users/hyang/Desktop/original/processed/jar-18.gif
# Processed dog-1.gif → /Users/hyang/Desktop/original/processed/dog-1.gif
# Processed Bone-15.gif → /Users/hyang/Desktop/original/processed/Bone-15.gif
# Processed sea_snake-20.gif → /Users/hyang/Desktop/original/processed/sea_snake-20.gif
# Processed beetle-13.gif → /Users/hyang/Desktop/original/processed/beetle-13.gif
# Processed classic-8.gif → /Users/hyang/Desktop/original/processed/classic-8.gif
# Processed hammer-20.gif → /Users/hyang/Desktop/original/processed/hammer-20.gif
# Processed cellular_phone-4.gif → /Users/hyang/Desktop/original/processed/cellular_phone-4.gif
# Processed frog-12.gif → /Users/hyang/Desktop/original/processed/frog-12.gif
# Processed pocket-1.gif → /Users/hyang/Desktop/original/processed/pocket-1.gif
# Processed device5-13.gif → /Users/hyang/Desktop/original/processed/device5-13.gif
# Processed tree-11.gif → /Users/hyang/Desktop/original/processed/tree-11.gif
# Processed Bone-9.gif → /Users/hyang/Desktop/original/processed/Bone-9.gif
# Processed personal_car-16.gif → /Users/hyang/Desktop/original/processed/personal_car-16.gif
# Processed spring-1.gif → /Users/hyang/Desktop/original/processed/spring-1.gif
# Processed camel-5.gif → /Users/hyang/Desktop/original/processed/camel-5.gif
# Processed beetle-9.gif → /Users/hyang/Desktop/original/processed/beetle-9.gif
# Processed device2-8.gif → /Users/hyang/Desktop/original/processed/device2-8.gif
# Processed hat-16.gif → /Users/hyang/Desktop/original/processed/hat-16.gif
# Processed guitar-1.gif → /Users/hyang/Desktop/original/processed/guitar-1.gif
# Processed chicken-6.gif → /Users/hyang/Desktop/original/processed/chicken-6.gif
# Processed ray-1.gif → /Users/hyang/Desktop/original/processed/ray-1.gif
# Processed chicken-7.gif → /Users/hyang/Desktop/original/processed/chicken-7.gif
# Processed hat-17.gif → /Users/hyang/Desktop/original/processed/hat-17.gif
# Processed device2-9.gif → /Users/hyang/Desktop/original/processed/device2-9.gif
# Processed guitar-20.gif → /Users/hyang/Desktop/original/processed/guitar-20.gif
# Processed beetle-8.gif → /Users/hyang/Desktop/original/processed/beetle-8.gif
# Processed personal_car-17.gif → /Users/hyang/Desktop/original/processed/personal_car-17.gif
# Processed Bone-8.gif → /Users/hyang/Desktop/original/processed/Bone-8.gif
# Processed camel-4.gif → /Users/hyang/Desktop/original/processed/camel-4.gif
# Processed tree-10.gif → /Users/hyang/Desktop/original/processed/tree-10.gif
# Processed device5-12.gif → /Users/hyang/Desktop/original/processed/device5-12.gif
# Processed classic-9.gif → /Users/hyang/Desktop/original/processed/classic-9.gif
# Processed beetle-12.gif → /Users/hyang/Desktop/original/processed/beetle-12.gif
# Processed frog-13.gif → /Users/hyang/Desktop/original/processed/frog-13.gif
# Processed cellular_phone-5.gif → /Users/hyang/Desktop/original/processed/cellular_phone-5.gif
# Processed Bone-14.gif → /Users/hyang/Desktop/original/processed/Bone-14.gif
# Processed jar-19.gif → /Users/hyang/Desktop/original/processed/jar-19.gif
# Processed device9-12.gif → /Users/hyang/Desktop/original/processed/device9-12.gif
# Processed device8-2.gif → /Users/hyang/Desktop/original/processed/device8-2.gif
# Processed horse-7.gif → /Users/hyang/Desktop/original/processed/horse-7.gif
# Processed cattle-5.gif → /Users/hyang/Desktop/original/processed/cattle-5.gif
# Processed pocket-12.gif → /Users/hyang/Desktop/original/processed/pocket-12.gif
# Processed device7-17.gif → /Users/hyang/Desktop/original/processed/device7-17.gif
# Processed rat-19.gif → /Users/hyang/Desktop/original/processed/rat-19.gif
# Processed Comma-4.gif → /Users/hyang/Desktop/original/processed/Comma-4.gif
# Processed shoe-5.gif → /Users/hyang/Desktop/original/processed/shoe-5.gif
# Processed spoon-1.gif → /Users/hyang/Desktop/original/processed/spoon-1.gif
# Processed horseshoe-13.gif → /Users/hyang/Desktop/original/processed/horseshoe-13.gif
# Processed hat-2.gif → /Users/hyang/Desktop/original/processed/hat-2.gif
# Processed chicken-12.gif → /Users/hyang/Desktop/original/processed/chicken-12.gif
# Processed elephant-8.gif → /Users/hyang/Desktop/original/processed/elephant-8.gif
# Processed shoe-19.gif → /Users/hyang/Desktop/original/processed/shoe-19.gif
# Processed octopus-19.gif → /Users/hyang/Desktop/original/processed/octopus-19.gif
# Processed bell-7.gif → /Users/hyang/Desktop/original/processed/bell-7.gif
# Processed watch-12.gif → /Users/hyang/Desktop/original/processed/watch-12.gif
# Processed key-18.gif → /Users/hyang/Desktop/original/processed/key-18.gif
# Processed bat-14.gif → /Users/hyang/Desktop/original/processed/bat-14.gif
# Processed teddy-18.gif → /Users/hyang/Desktop/original/processed/teddy-18.gif
# Processed apple-1.gif → /Users/hyang/Desktop/original/processed/apple-1.gif
# Processed face-1.gif → /Users/hyang/Desktop/original/processed/face-1.gif
# Processed children-7.gif → /Users/hyang/Desktop/original/processed/children-7.gif
# Processed lmfish-5.gif → /Users/hyang/Desktop/original/processed/lmfish-5.gif
# Processed dog-12.gif → /Users/hyang/Desktop/original/processed/dog-12.gif
# Processed pencil-16.gif → /Users/hyang/Desktop/original/processed/pencil-16.gif
# Processed carriage-08.gif → /Users/hyang/Desktop/original/processed/carriage-08.gif
# Processed hammer-4.gif → /Users/hyang/Desktop/original/processed/hammer-4.gif
# Processed Glas-5.gif → /Users/hyang/Desktop/original/processed/Glas-5.gif
# Processed confusions.gif → /Users/hyang/Desktop/original/processed/confusions.gif
# Processed apple-13.gif → /Users/hyang/Desktop/original/processed/apple-13.gif
# Processed frog-9.gif → /Users/hyang/Desktop/original/processed/frog-9.gif
# Processed children-15.gif → /Users/hyang/Desktop/original/processed/children-15.gif
# Processed carriage-20.gif → /Users/hyang/Desktop/original/processed/carriage-20.gif
# Processed bat-6.gif → /Users/hyang/Desktop/original/processed/bat-6.gif
# Processed jar-6.gif → /Users/hyang/Desktop/original/processed/jar-6.gif
# Processed chopper-07.gif → /Users/hyang/Desktop/original/processed/chopper-07.gif
# Processed bird-7.gif → /Users/hyang/Desktop/original/processed/bird-7.gif
# Processed chopper-13.gif → /Users/hyang/Desktop/original/processed/chopper-13.gif
# Processed ray-16.gif → /Users/hyang/Desktop/original/processed/ray-16.gif
# Processed device3-14.gif → /Users/hyang/Desktop/original/processed/device3-14.gif
# Processed horseshoe-8.gif → /Users/hyang/Desktop/original/processed/horseshoe-8.gif
# Processed crown-6.gif → /Users/hyang/Desktop/original/processed/crown-6.gif
# Processed truck-10.gif → /Users/hyang/Desktop/original/processed/truck-10.gif
# Processed truck-04.gif → /Users/hyang/Desktop/original/processed/truck-04.gif
# Processed cup-6.gif → /Users/hyang/Desktop/original/processed/cup-6.gif
# Processed tree-8.gif → /Users/hyang/Desktop/original/processed/tree-8.gif
# Processed flatfish-11.gif → /Users/hyang/Desktop/original/processed/flatfish-11.gif
# Processed classic-11.gif → /Users/hyang/Desktop/original/processed/classic-11.gif
# Processed lmfish-14.gif → /Users/hyang/Desktop/original/processed/lmfish-14.gif
# Processed fish-14.gif → /Users/hyang/Desktop/original/processed/fish-14.gif
# Processed turtle-11.gif → /Users/hyang/Desktop/original/processed/turtle-11.gif
# Processed spring-13.gif → /Users/hyang/Desktop/original/processed/spring-13.gif
# Processed elephant-12.gif → /Users/hyang/Desktop/original/processed/elephant-12.gif
# Processed cup-12.gif → /Users/hyang/Desktop/original/processed/cup-12.gif
# Processed car-06.gif → /Users/hyang/Desktop/original/processed/car-06.gif
# Processed horse-13.gif → /Users/hyang/Desktop/original/processed/horse-13.gif
# Processed car-12.gif → /Users/hyang/Desktop/original/processed/car-12.gif
# Processed device9-5.gif → /Users/hyang/Desktop/original/processed/device9-5.gif
# Processed HCircle-14.gif → /Users/hyang/Desktop/original/processed/HCircle-14.gif
# Processed device5-8.gif → /Users/hyang/Desktop/original/processed/device5-8.gif
# Processed sea_snake-7.gif → /Users/hyang/Desktop/original/processed/sea_snake-7.gif
# Processed spoon-10.gif → /Users/hyang/Desktop/original/processed/spoon-10.gif
# Processed fork-19.gif → /Users/hyang/Desktop/original/processed/fork-19.gif
# Processed bell-19.gif → /Users/hyang/Desktop/original/processed/bell-19.gif
# Processed Misk-9.gif → /Users/hyang/Desktop/original/processed/Misk-9.gif
# Processed flatfish-6.gif → /Users/hyang/Desktop/original/processed/flatfish-6.gif
# Processed lizzard-17.gif → /Users/hyang/Desktop/original/processed/lizzard-17.gif
# Processed pencil-2.gif → /Users/hyang/Desktop/original/processed/pencil-2.gif
# Processed butterfly-6.gif → /Users/hyang/Desktop/original/processed/butterfly-6.gif
# Processed device6-18.gif → /Users/hyang/Desktop/original/processed/device6-18.gif
# Processed device1-11.gif → /Users/hyang/Desktop/original/processed/device1-11.gif
# Processed device6-19.gif → /Users/hyang/Desktop/original/processed/device6-19.gif
# Processed device1-10.gif → /Users/hyang/Desktop/original/processed/device1-10.gif
# Processed butterfly-7.gif → /Users/hyang/Desktop/original/processed/butterfly-7.gif
# Processed pencil-3.gif → /Users/hyang/Desktop/original/processed/pencil-3.gif
# Processed device8-20.gif → /Users/hyang/Desktop/original/processed/device8-20.gif
# Processed lizzard-16.gif → /Users/hyang/Desktop/original/processed/lizzard-16.gif
# Processed flatfish-7.gif → /Users/hyang/Desktop/original/processed/flatfish-7.gif
# Processed Misk-8.gif → /Users/hyang/Desktop/original/processed/Misk-8.gif
# Processed bell-18.gif → /Users/hyang/Desktop/original/processed/bell-18.gif
# Processed fork-18.gif → /Users/hyang/Desktop/original/processed/fork-18.gif
# Processed spoon-11.gif → /Users/hyang/Desktop/original/processed/spoon-11.gif
# Processed sea_snake-6.gif → /Users/hyang/Desktop/original/processed/sea_snake-6.gif
# Processed device5-9.gif → /Users/hyang/Desktop/original/processed/device5-9.gif
# Processed HCircle-15.gif → /Users/hyang/Desktop/original/processed/HCircle-15.gif
# Processed horse-12.gif → /Users/hyang/Desktop/original/processed/horse-12.gif
# Processed device9-4.gif → /Users/hyang/Desktop/original/processed/device9-4.gif
# Processed car-13.gif → /Users/hyang/Desktop/original/processed/car-13.gif
# Processed car-07.gif → /Users/hyang/Desktop/original/processed/car-07.gif
# Processed Comma-20.gif → /Users/hyang/Desktop/original/processed/Comma-20.gif
# Processed cup-13.gif → /Users/hyang/Desktop/original/processed/cup-13.gif
# Processed elephant-13.gif → /Users/hyang/Desktop/original/processed/elephant-13.gif
# Processed turtle-10.gif → /Users/hyang/Desktop/original/processed/turtle-10.gif
# Processed fish-15.gif → /Users/hyang/Desktop/original/processed/fish-15.gif
# Processed spring-12.gif → /Users/hyang/Desktop/original/processed/spring-12.gif
# Processed classic-10.gif → /Users/hyang/Desktop/original/processed/classic-10.gif
# Processed lmfish-15.gif → /Users/hyang/Desktop/original/processed/lmfish-15.gif
# Processed tree-9.gif → /Users/hyang/Desktop/original/processed/tree-9.gif
# Processed flatfish-10.gif → /Users/hyang/Desktop/original/processed/flatfish-10.gif
# Processed face-20.gif → /Users/hyang/Desktop/original/processed/face-20.gif
# Processed cup-7.gif → /Users/hyang/Desktop/original/processed/cup-7.gif
# Processed butterfly-20.gif → /Users/hyang/Desktop/original/processed/butterfly-20.gif
# Processed truck-05.gif → /Users/hyang/Desktop/original/processed/truck-05.gif
# Processed truck-11.gif → /Users/hyang/Desktop/original/processed/truck-11.gif
# Processed crown-7.gif → /Users/hyang/Desktop/original/processed/crown-7.gif
# Processed horseshoe-9.gif → /Users/hyang/Desktop/original/processed/horseshoe-9.gif
# Processed device3-15.gif → /Users/hyang/Desktop/original/processed/device3-15.gif
# Processed cellular_phone-20.gif → /Users/hyang/Desktop/original/processed/cellular_phone-20.gif
# Processed chopper-12.gif → /Users/hyang/Desktop/original/processed/chopper-12.gif
# Processed device4-20.gif → /Users/hyang/Desktop/original/processed/device4-20.gif
# Processed ray-17.gif → /Users/hyang/Desktop/original/processed/ray-17.gif
# Processed bat-7.gif → /Users/hyang/Desktop/original/processed/bat-7.gif
# Processed bird-6.gif → /Users/hyang/Desktop/original/processed/bird-6.gif
# Processed chopper-06.gif → /Users/hyang/Desktop/original/processed/chopper-06.gif
# Processed jar-7.gif → /Users/hyang/Desktop/original/processed/jar-7.gif
# Processed children-14.gif → /Users/hyang/Desktop/original/processed/children-14.gif
# Processed frog-8.gif → /Users/hyang/Desktop/original/processed/frog-8.gif
# Processed apple-12.gif → /Users/hyang/Desktop/original/processed/apple-12.gif
# Processed carriage-09.gif → /Users/hyang/Desktop/original/processed/carriage-09.gif
# Processed Glas-4.gif → /Users/hyang/Desktop/original/processed/Glas-4.gif
# Processed hammer-5.gif → /Users/hyang/Desktop/original/processed/hammer-5.gif
# Processed apple-10.gif → /Users/hyang/Desktop/original/processed/apple-10.gif
# Processed hammer-7.gif → /Users/hyang/Desktop/original/processed/hammer-7.gif
# Processed Glas-6.gif → /Users/hyang/Desktop/original/processed/Glas-6.gif
# Processed children-16.gif → /Users/hyang/Desktop/original/processed/children-16.gif
# Processed fly-19.gif → /Users/hyang/Desktop/original/processed/fly-19.gif
# Processed ray-15.gif → /Users/hyang/Desktop/original/processed/ray-15.gif
# Processed chopper-10.gif → /Users/hyang/Desktop/original/processed/chopper-10.gif
# Processed jar-5.gif → /Users/hyang/Desktop/original/processed/jar-5.gif
# Processed chopper-04.gif → /Users/hyang/Desktop/original/processed/chopper-04.gif
# Processed bird-4.gif → /Users/hyang/Desktop/original/processed/bird-4.gif
# Processed bat-5.gif → /Users/hyang/Desktop/original/processed/bat-5.gif
# Processed device3-17.gif → /Users/hyang/Desktop/original/processed/device3-17.gif
# Processed fly-8.gif → /Users/hyang/Desktop/original/processed/fly-8.gif
# Processed crown-5.gif → /Users/hyang/Desktop/original/processed/crown-5.gif
# Processed truck-07.gif → /Users/hyang/Desktop/original/processed/truck-07.gif
# Processed truck-13.gif → /Users/hyang/Desktop/original/processed/truck-13.gif
# Processed flatfish-12.gif → /Users/hyang/Desktop/original/processed/flatfish-12.gif
# Processed cup-5.gif → /Users/hyang/Desktop/original/processed/cup-5.gif
# Processed lmfish-17.gif → /Users/hyang/Desktop/original/processed/lmfish-17.gif
# Processed classic-12.gif → /Users/hyang/Desktop/original/processed/classic-12.gif
# Processed device7-9.gif → /Users/hyang/Desktop/original/processed/device7-9.gif
# Processed stef-18.gif → /Users/hyang/Desktop/original/processed/stef-18.gif
# Processed cup-11.gif → /Users/hyang/Desktop/original/processed/cup-11.gif
# Processed elephant-11.gif → /Users/hyang/Desktop/original/processed/elephant-11.gif
# Processed spring-10.gif → /Users/hyang/Desktop/original/processed/spring-10.gif
# Processed fish-17.gif → /Users/hyang/Desktop/original/processed/fish-17.gif
# Processed turtle-12.gif → /Users/hyang/Desktop/original/processed/turtle-12.gif
# Processed car-11.gif → /Users/hyang/Desktop/original/processed/car-11.gif
# Processed device9-6.gif → /Users/hyang/Desktop/original/processed/device9-6.gif
# Processed horse-10.gif → /Users/hyang/Desktop/original/processed/horse-10.gif
# Processed car-05.gif → /Users/hyang/Desktop/original/processed/car-05.gif
# Processed HCircle-17.gif → /Users/hyang/Desktop/original/processed/HCircle-17.gif
# Processed sea_snake-4.gif → /Users/hyang/Desktop/original/processed/sea_snake-4.gif
# Processed spoon-13.gif → /Users/hyang/Desktop/original/processed/spoon-13.gif
# Processed flatfish-5.gif → /Users/hyang/Desktop/original/processed/flatfish-5.gif
# Processed lizzard-14.gif → /Users/hyang/Desktop/original/processed/lizzard-14.gif
# Processed cattle-20.gif → /Users/hyang/Desktop/original/processed/cattle-20.gif
# Processed device1-12.gif → /Users/hyang/Desktop/original/processed/device1-12.gif
# Processed pencil-1.gif → /Users/hyang/Desktop/original/processed/pencil-1.gif
# Processed butterfly-5.gif → /Users/hyang/Desktop/original/processed/butterfly-5.gif
# Processed butterfly-4.gif → /Users/hyang/Desktop/original/processed/butterfly-4.gif
# Processed device1-13.gif → /Users/hyang/Desktop/original/processed/device1-13.gif
# Processed lizzard-15.gif → /Users/hyang/Desktop/original/processed/lizzard-15.gif
# Processed flatfish-4.gif → /Users/hyang/Desktop/original/processed/flatfish-4.gif
# Processed spoon-12.gif → /Users/hyang/Desktop/original/processed/spoon-12.gif
# Processed sea_snake-5.gif → /Users/hyang/Desktop/original/processed/sea_snake-5.gif
# Processed Heart-20.gif → /Users/hyang/Desktop/original/processed/Heart-20.gif
# Processed HCircle-16.gif → /Users/hyang/Desktop/original/processed/HCircle-16.gif
# Processed car-04.gif → /Users/hyang/Desktop/original/processed/car-04.gif
# Processed device9-7.gif → /Users/hyang/Desktop/original/processed/device9-7.gif
# Processed car-10.gif → /Users/hyang/Desktop/original/processed/car-10.gif
# Processed horse-11.gif → /Users/hyang/Desktop/original/processed/horse-11.gif
# Processed spring-11.gif → /Users/hyang/Desktop/original/processed/spring-11.gif
# Processed turtle-13.gif → /Users/hyang/Desktop/original/processed/turtle-13.gif
# Processed fish-16.gif → /Users/hyang/Desktop/original/processed/fish-16.gif
# Processed stef-19.gif → /Users/hyang/Desktop/original/processed/stef-19.gif
# Processed elephant-10.gif → /Users/hyang/Desktop/original/processed/elephant-10.gif
# Processed cup-10.gif → /Users/hyang/Desktop/original/processed/cup-10.gif
# Processed lmfish-16.gif → /Users/hyang/Desktop/original/processed/lmfish-16.gif
# Processed device7-8.gif → /Users/hyang/Desktop/original/processed/device7-8.gif
# Processed classic-13.gif → /Users/hyang/Desktop/original/processed/classic-13.gif
# Processed cup-4.gif → /Users/hyang/Desktop/original/processed/cup-4.gif
# Processed flatfish-13.gif → /Users/hyang/Desktop/original/processed/flatfish-13.gif
# Processed truck-12.gif → /Users/hyang/Desktop/original/processed/truck-12.gif
# Processed truck-06.gif → /Users/hyang/Desktop/original/processed/truck-06.gif
# Processed crown-4.gif → /Users/hyang/Desktop/original/processed/crown-4.gif
# Processed fly-9.gif → /Users/hyang/Desktop/original/processed/fly-9.gif
# Processed device3-16.gif → /Users/hyang/Desktop/original/processed/device3-16.gif
# Processed bird-5.gif → /Users/hyang/Desktop/original/processed/bird-5.gif
# Processed chopper-05.gif → /Users/hyang/Desktop/original/processed/chopper-05.gif
# Processed jar-4.gif → /Users/hyang/Desktop/original/processed/jar-4.gif
# Processed bat-4.gif → /Users/hyang/Desktop/original/processed/bat-4.gif
# Processed ray-14.gif → /Users/hyang/Desktop/original/processed/ray-14.gif
# Processed chopper-11.gif → /Users/hyang/Desktop/original/processed/chopper-11.gif
# Processed fly-18.gif → /Users/hyang/Desktop/original/processed/fly-18.gif
# Processed children-17.gif → /Users/hyang/Desktop/original/processed/children-17.gif
# Processed Glas-7.gif → /Users/hyang/Desktop/original/processed/Glas-7.gif
# Processed hammer-6.gif → /Users/hyang/Desktop/original/processed/hammer-6.gif
# Processed apple-11.gif → /Users/hyang/Desktop/original/processed/apple-11.gif
# Processed children-13.gif → /Users/hyang/Desktop/original/processed/children-13.gif
# Processed fly-20.gif → /Users/hyang/Desktop/original/processed/fly-20.gif
# Processed apple-15.gif → /Users/hyang/Desktop/original/processed/apple-15.gif
# Processed device3-8.gif → /Users/hyang/Desktop/original/processed/device3-8.gif
# Processed Glas-3.gif → /Users/hyang/Desktop/original/processed/Glas-3.gif
# Processed hammer-2.gif → /Users/hyang/Desktop/original/processed/hammer-2.gif
# Processed device3-12.gif → /Users/hyang/Desktop/original/processed/device3-12.gif
# Processed lizzard-8.gif → /Users/hyang/Desktop/original/processed/lizzard-8.gif
# Processed chopper-15.gif → /Users/hyang/Desktop/original/processed/chopper-15.gif
# Processed ray-10.gif → /Users/hyang/Desktop/original/processed/ray-10.gif
# Processed chopper-01.gif → /Users/hyang/Desktop/original/processed/chopper-01.gif
# Processed bird-1.gif → /Users/hyang/Desktop/original/processed/bird-1.gif
# Processed flatfish-17.gif → /Users/hyang/Desktop/original/processed/flatfish-17.gif
# Processed truck-02.gif → /Users/hyang/Desktop/original/processed/truck-02.gif
# Processed truck-16.gif → /Users/hyang/Desktop/original/processed/truck-16.gif
# Processed cup-14.gif → /Users/hyang/Desktop/original/processed/cup-14.gif
# Processed elephant-14.gif → /Users/hyang/Desktop/original/processed/elephant-14.gif
# Processed fish-12.gif → /Users/hyang/Desktop/original/processed/fish-12.gif
# Processed stef-09.gif → /Users/hyang/Desktop/original/processed/stef-09.gif
# Processed turtle-17.gif → /Users/hyang/Desktop/original/processed/turtle-17.gif
# Processed spring-15.gif → /Users/hyang/Desktop/original/processed/spring-15.gif
# Processed classic-17.gif → /Users/hyang/Desktop/original/processed/classic-17.gif
# Processed turtle-8.gif → /Users/hyang/Desktop/original/processed/turtle-8.gif
# Processed fork-9.gif → /Users/hyang/Desktop/original/processed/fork-9.gif
# Processed lmfish-12.gif → /Users/hyang/Desktop/original/processed/lmfish-12.gif
# Processed HCircle-8.gif → /Users/hyang/Desktop/original/processed/HCircle-8.gif
# Processed HCircle-12.gif → /Users/hyang/Desktop/original/processed/HCircle-12.gif
# Processed horse-15.gif → /Users/hyang/Desktop/original/processed/horse-15.gif
# Processed car-14.gif → /Users/hyang/Desktop/original/processed/car-14.gif
# Processed device9-3.gif → /Users/hyang/Desktop/original/processed/device9-3.gif
# Processed Heart-18.gif → /Users/hyang/Desktop/original/processed/Heart-18.gif
# Processed sea_snake-1.gif → /Users/hyang/Desktop/original/processed/sea_snake-1.gif
# Processed spoon-16.gif → /Users/hyang/Desktop/original/processed/spoon-16.gif
# Processed device1-17.gif → /Users/hyang/Desktop/original/processed/device1-17.gif
# Processed cattle-19.gif → /Users/hyang/Desktop/original/processed/cattle-19.gif
# Processed pencil-4.gif → /Users/hyang/Desktop/original/processed/pencil-4.gif
# Processed lizzard-11.gif → /Users/hyang/Desktop/original/processed/lizzard-11.gif
# Processed lizzard-10.gif → /Users/hyang/Desktop/original/processed/lizzard-10.gif
# Processed pencil-5.gif → /Users/hyang/Desktop/original/processed/pencil-5.gif
# Processed butterfly-1.gif → /Users/hyang/Desktop/original/processed/butterfly-1.gif
# Processed cattle-18.gif → /Users/hyang/Desktop/original/processed/cattle-18.gif
# Processed device1-16.gif → /Users/hyang/Desktop/original/processed/device1-16.gif
# Processed spoon-17.gif → /Users/hyang/Desktop/original/processed/spoon-17.gif
# Processed Heart-19.gif → /Users/hyang/Desktop/original/processed/Heart-19.gif
# Processed flatfish-1.gif → /Users/hyang/Desktop/original/processed/flatfish-1.gif
# Processed car-01.gif → /Users/hyang/Desktop/original/processed/car-01.gif
# Processed horse-14.gif → /Users/hyang/Desktop/original/processed/horse-14.gif
# Processed device9-2.gif → /Users/hyang/Desktop/original/processed/device9-2.gif
# Processed car-15.gif → /Users/hyang/Desktop/original/processed/car-15.gif
# Processed HCircle-13.gif → /Users/hyang/Desktop/original/processed/HCircle-13.gif
# Processed HCircle-9.gif → /Users/hyang/Desktop/original/processed/HCircle-9.gif
# Processed turtle-9.gif → /Users/hyang/Desktop/original/processed/turtle-9.gif
# Processed classic-16.gif → /Users/hyang/Desktop/original/processed/classic-16.gif
# Processed lmfish-13.gif → /Users/hyang/Desktop/original/processed/lmfish-13.gif
# Processed fork-8.gif → /Users/hyang/Desktop/original/processed/fork-8.gif
# Processed stef-20.gif → /Users/hyang/Desktop/original/processed/stef-20.gif
# Processed turtle-16.gif → /Users/hyang/Desktop/original/processed/turtle-16.gif
# Processed stef-08.gif → /Users/hyang/Desktop/original/processed/stef-08.gif
# Processed fish-13.gif → /Users/hyang/Desktop/original/processed/fish-13.gif
# Processed spring-14.gif → /Users/hyang/Desktop/original/processed/spring-14.gif
# Processed elephant-15.gif → /Users/hyang/Desktop/original/processed/elephant-15.gif
# Processed cup-15.gif → /Users/hyang/Desktop/original/processed/cup-15.gif
# Processed truck-17.gif → /Users/hyang/Desktop/original/processed/truck-17.gif
# Processed truck-03.gif → /Users/hyang/Desktop/original/processed/truck-03.gif
# Processed cup-1.gif → /Users/hyang/Desktop/original/processed/cup-1.gif
# Processed flatfish-16.gif → /Users/hyang/Desktop/original/processed/flatfish-16.gif
# Processed crown-1.gif → /Users/hyang/Desktop/original/processed/crown-1.gif
# Processed bat-1.gif → /Users/hyang/Desktop/original/processed/bat-1.gif
# Processed jar-1.gif → /Users/hyang/Desktop/original/processed/jar-1.gif
# Processed chopper-14.gif → /Users/hyang/Desktop/original/processed/chopper-14.gif
# Processed ray-11.gif → /Users/hyang/Desktop/original/processed/ray-11.gif
# Processed lizzard-9.gif → /Users/hyang/Desktop/original/processed/lizzard-9.gif
# ...
# Processed camel-10.gif → /Users/hyang/Desktop/original/processed/camel-10.gif
# Processed shoe-16.gif → /Users/hyang/Desktop/original/processed/shoe-16.gif
# Processed Heart-5.gif → /Users/hyang/Desktop/original/processed/Heart-5.gif
# Processed octopus-16.gif → /Users/hyang/Desktop/original/processed/octopus-16.gif
# Processed Misk-15.gif → /Users/hyang/Desktop/original/processed/Misk-15.gif
# Processed bell-8.gif → /Users/hyang/Desktop/original/processed/bell-8.gif
# Processed key-17.gif → /Users/hyang/Desktop/original/processed/key-17.gif
# Processed deer-5.gif → /Users/hyang/Desktop/original/processed/deer-5.gif
# Processed teddy-03.gif → /Users/hyang/Desktop/original/processed/teddy-03.gif
# Processed deer-15.gif → /Users/hyang/Desktop/original/processed/deer-15.gif
# Processed teddy-17.gif → /Users/hyang/Desktop/original/processed/teddy-17.gif
# Processed watch-2.gif → /Users/hyang/Desktop/original/processed/watch-2.gif
# Processed children-8.gif → /Users/hyang/Desktop/original/processed/children-8.gif
# Processed pencil-19.gif → /Users/hyang/Desktop/original/processed/pencil-19.gif
# Processed watch-6.gif → /Users/hyang/Desktop/original/processed/watch-6.gif
# Processed device4-4.gif → /Users/hyang/Desktop/original/processed/device4-4.gif
# Processed dog-19.gif → /Users/hyang/Desktop/original/processed/dog-19.gif
# Processed deer-1.gif → /Users/hyang/Desktop/original/processed/deer-1.gif
# Processed key-13.gif → /Users/hyang/Desktop/original/processed/key-13.gif
# Processed teddy-13.gif → /Users/hyang/Desktop/original/processed/teddy-13.gif
# Processed deer-11.gif → /Users/hyang/Desktop/original/processed/deer-11.gif
# Processed teddy-07.gif → /Users/hyang/Desktop/original/processed/teddy-07.gif
# Processed camel-14.gif → /Users/hyang/Desktop/original/processed/camel-14.gif
# Processed hat-9.gif → /Users/hyang/Desktop/original/processed/hat-9.gif
# Processed device6-6.gif → /Users/hyang/Desktop/original/processed/device6-6.gif
# Processed chicken-19.gif → /Users/hyang/Desktop/original/processed/chicken-19.gif
# Processed elephant-3.gif → /Users/hyang/Desktop/original/processed/elephant-3.gif
# Processed Misk-11.gif → /Users/hyang/Desktop/original/processed/Misk-11.gif
# Processed watch-19.gif → /Users/hyang/Desktop/original/processed/watch-19.gif
# Processed octopus-12.gif → /Users/hyang/Desktop/original/processed/octopus-12.gif
# Processed shoe-12.gif → /Users/hyang/Desktop/original/processed/shoe-12.gif
# Processed Heart-1.gif → /Users/hyang/Desktop/original/processed/Heart-1.gif
# Processed device8-9.gif → /Users/hyang/Desktop/original/processed/device8-9.gif
# Processed device9-19.gif → /Users/hyang/Desktop/original/processed/device9-19.gif
# Processed jar-12.gif → /Users/hyang/Desktop/original/processed/jar-12.gif
# Processed device7-20.gif → /Users/hyang/Desktop/original/processed/device7-20.gif
# Processed bird-11.gif → /Users/hyang/Desktop/original/processed/bird-11.gif
# Processed rat-12.gif → /Users/hyang/Desktop/original/processed/rat-12.gif
# Processed crown-10.gif → /Users/hyang/Desktop/original/processed/crown-10.gif
# Processed horseshoe-18.gif → /Users/hyang/Desktop/original/processed/horseshoe-18.gif
# Processed pocket-19.gif → /Users/hyang/Desktop/original/processed/pocket-19.gif
# Processed device0-15.gif → /Users/hyang/Desktop/original/processed/device0-15.gif
# Processed rat-06.gif → /Users/hyang/Desktop/original/processed/rat-06.gif
# Processed beetle-19.gif → /Users/hyang/Desktop/original/processed/beetle-19.gif
# Processed classic-2.gif → /Users/hyang/Desktop/original/processed/classic-2.gif
# Processed frog-18.gif → /Users/hyang/Desktop/original/processed/frog-18.gif
# Processed sea_snake-16.gif → /Users/hyang/Desktop/original/processed/sea_snake-16.gif
# Processed brick-04.gif → /Users/hyang/Desktop/original/processed/brick-04.gif
# Processed hammer-16.gif → /Users/hyang/Desktop/original/processed/hammer-16.gif
# Processed brick-10.gif → /Users/hyang/Desktop/original/processed/brick-10.gif
# Processed Glas-15.gif → /Users/hyang/Desktop/original/processed/Glas-15.gif
# Processed device5-19.gif → /Users/hyang/Desktop/original/processed/device5-19.gif
# Processed fish-4.gif → /Users/hyang/Desktop/original/processed/fish-4.gif
# Processed device2-10.gif → /Users/hyang/Desktop/original/processed/device2-10.gif
# Processed personal_car-20.gif → /Users/hyang/Desktop/original/processed/personal_car-20.gif
# Processed device2-2.gif → /Users/hyang/Desktop/original/processed/device2-2.gif
# Processed personal_car-4.gif → /Users/hyang/Desktop/original/processed/personal_car-4.gif
# Processed guitar-17.gif → /Users/hyang/Desktop/original/processed/guitar-17.gif
# Processed bottle-04.gif → /Users/hyang/Desktop/original/processed/bottle-04.gif
# Processed Bone-3.gif → /Users/hyang/Desktop/original/processed/Bone-3.gif
# Processed hat-20.gif → /Users/hyang/Desktop/original/processed/hat-20.gif
# Processed beetle-3.gif → /Users/hyang/Desktop/original/processed/beetle-3.gif
# Processed bottle-10.gif → /Users/hyang/Desktop/original/processed/bottle-10.gif
# Processed fountain-04.gif → /Users/hyang/Desktop/original/processed/fountain-04.gif
# Processed fountain-10.gif → /Users/hyang/Desktop/original/processed/fountain-10.gif
# Processed fountain-11.gif → /Users/hyang/Desktop/original/processed/fountain-11.gif
# Processed fountain-05.gif → /Users/hyang/Desktop/original/processed/fountain-05.gif
# Processed beetle-2.gif → /Users/hyang/Desktop/original/processed/beetle-2.gif
# Processed bottle-11.gif → /Users/hyang/Desktop/original/processed/bottle-11.gif
# Processed Bone-2.gif → /Users/hyang/Desktop/original/processed/Bone-2.gif
# Processed bottle-05.gif → /Users/hyang/Desktop/original/processed/bottle-05.gif
# Processed guitar-16.gif → /Users/hyang/Desktop/original/processed/guitar-16.gif
# Processed personal_car-5.gif → /Users/hyang/Desktop/original/processed/personal_car-5.gif
# Processed device2-3.gif → /Users/hyang/Desktop/original/processed/device2-3.gif
# Processed device5-18.gif → /Users/hyang/Desktop/original/processed/device5-18.gif
# Processed device2-11.gif → /Users/hyang/Desktop/original/processed/device2-11.gif
# Processed fish-5.gif → /Users/hyang/Desktop/original/processed/fish-5.gif
# Processed Glas-14.gif → /Users/hyang/Desktop/original/processed/Glas-14.gif
# Processed brick-11.gif → /Users/hyang/Desktop/original/processed/brick-11.gif
# Processed hammer-17.gif → /Users/hyang/Desktop/original/processed/hammer-17.gif
# Processed brick-05.gif → /Users/hyang/Desktop/original/processed/brick-05.gif
# Processed sea_snake-17.gif → /Users/hyang/Desktop/original/processed/sea_snake-17.gif
# Processed classic-3.gif → /Users/hyang/Desktop/original/processed/classic-3.gif
# Processed beetle-18.gif → /Users/hyang/Desktop/original/processed/beetle-18.gif
# Processed frog-19.gif → /Users/hyang/Desktop/original/processed/frog-19.gif
# Processed device0-1.gif → /Users/hyang/Desktop/original/processed/device0-1.gif
# Processed device0-14.gif → /Users/hyang/Desktop/original/processed/device0-14.gif
# Processed pocket-18.gif → /Users/hyang/Desktop/original/processed/pocket-18.gif
# Processed rat-07.gif → /Users/hyang/Desktop/original/processed/rat-07.gif
# Processed rat-13.gif → /Users/hyang/Desktop/original/processed/rat-13.gif
# Processed bird-10.gif → /Users/hyang/Desktop/original/processed/bird-10.gif
# Processed horseshoe-19.gif → /Users/hyang/Desktop/original/processed/horseshoe-19.gif
# Processed crown-11.gif → /Users/hyang/Desktop/original/processed/crown-11.gif
# Processed jar-13.gif → /Users/hyang/Desktop/original/processed/jar-13.gif
# Processed device9-18.gif → /Users/hyang/Desktop/original/processed/device9-18.gif
# Processed device8-8.gif → /Users/hyang/Desktop/original/processed/device8-8.gif
# Processed shoe-13.gif → /Users/hyang/Desktop/original/processed/shoe-13.gif
# Processed octopus-13.gif → /Users/hyang/Desktop/original/processed/octopus-13.gif
# Processed watch-18.gif → /Users/hyang/Desktop/original/processed/watch-18.gif
# Processed Misk-10.gif → /Users/hyang/Desktop/original/processed/Misk-10.gif
# Processed hat-8.gif → /Users/hyang/Desktop/original/processed/hat-8.gif
# Processed elephant-2.gif → /Users/hyang/Desktop/original/processed/elephant-2.gif
# Processed chicken-18.gif → /Users/hyang/Desktop/original/processed/chicken-18.gif
# Processed device6-7.gif → /Users/hyang/Desktop/original/processed/device6-7.gif
# Processed camel-15.gif → /Users/hyang/Desktop/original/processed/camel-15.gif
# Processed teddy-06.gif → /Users/hyang/Desktop/original/processed/teddy-06.gif
# Processed teddy-12.gif → /Users/hyang/Desktop/original/processed/teddy-12.gif
# Processed deer-10.gif → /Users/hyang/Desktop/original/processed/deer-10.gif
# Processed key-12.gif → /Users/hyang/Desktop/original/processed/key-12.gif
# Processed dog-18.gif → /Users/hyang/Desktop/original/processed/dog-18.gif
# Processed device4-5.gif → /Users/hyang/Desktop/original/processed/device4-5.gif
# Processed watch-7.gif → /Users/hyang/Desktop/original/processed/watch-7.gif
# Processed pencil-20.gif → /Users/hyang/Desktop/original/processed/pencil-20.gif
# Processed apple-9.gif → /Users/hyang/Desktop/original/processed/apple-9.gif
# Processed watch-5.gif → /Users/hyang/Desktop/original/processed/watch-5.gif
# Processed device4-7.gif → /Users/hyang/Desktop/original/processed/device4-7.gif
# Processed face-9.gif → /Users/hyang/Desktop/original/processed/face-9.gif
# Processed key-10.gif → /Users/hyang/Desktop/original/processed/key-10.gif
# Processed deer-2.gif → /Users/hyang/Desktop/original/processed/deer-2.gif
# Processed teddy-04.gif → /Users/hyang/Desktop/original/processed/teddy-04.gif
# Processed bat-20.gif → /Users/hyang/Desktop/original/processed/bat-20.gif
# Processed deer-12.gif → /Users/hyang/Desktop/original/processed/deer-12.gif
# Processed teddy-10.gif → /Users/hyang/Desktop/original/processed/teddy-10.gif
# Processed device6-5.gif → /Users/hyang/Desktop/original/processed/device6-5.gif
# Processed camel-17.gif → /Users/hyang/Desktop/original/processed/camel-17.gif
# Processed octopus-11.gif → /Users/hyang/Desktop/original/processed/octopus-11.gif
# Processed shoe-11.gif → /Users/hyang/Desktop/original/processed/shoe-11.gif
# Processed Heart-2.gif → /Users/hyang/Desktop/original/processed/Heart-2.gif
# Processed Misk-12.gif → /Users/hyang/Desktop/original/processed/Misk-12.gif
# Processed jar-11.gif → /Users/hyang/Desktop/original/processed/jar-11.gif
# Processed rat-05.gif → /Users/hyang/Desktop/original/processed/rat-05.gif
# Processed device0-16.gif → /Users/hyang/Desktop/original/processed/device0-16.gif
# Processed crown-13.gif → /Users/hyang/Desktop/original/processed/crown-13.gif
# Processed spoon-9.gif → /Users/hyang/Desktop/original/processed/spoon-9.gif
# Processed bird-12.gif → /Users/hyang/Desktop/original/processed/bird-12.gif
# Processed rat-11.gif → /Users/hyang/Desktop/original/processed/rat-11.gif
# Processed Bone-20.gif → /Users/hyang/Desktop/original/processed/Bone-20.gif
# Processed sea_snake-15.gif → /Users/hyang/Desktop/original/processed/sea_snake-15.gif
# Processed device0-3.gif → /Users/hyang/Desktop/original/processed/device0-3.gif
# Processed classic-1.gif → /Users/hyang/Desktop/original/processed/classic-1.gif
# Processed brick-13.gif → /Users/hyang/Desktop/original/processed/brick-13.gif
# Processed dog-8.gif → /Users/hyang/Desktop/original/processed/dog-8.gif
# Processed brick-07.gif → /Users/hyang/Desktop/original/processed/brick-07.gif
# Processed hammer-15.gif → /Users/hyang/Desktop/original/processed/hammer-15.gif
# Processed tree-18.gif → /Users/hyang/Desktop/original/processed/tree-18.gif
# Processed fish-7.gif → /Users/hyang/Desktop/original/processed/fish-7.gif
# Processed device2-13.gif → /Users/hyang/Desktop/original/processed/device2-13.gif
# Processed pocket-8.gif → /Users/hyang/Desktop/original/processed/pocket-8.gif
# Processed Glas-16.gif → /Users/hyang/Desktop/original/processed/Glas-16.gif
# Processed personal_car-7.gif → /Users/hyang/Desktop/original/processed/personal_car-7.gif
# Processed guitar-8.gif → /Users/hyang/Desktop/original/processed/guitar-8.gif
# Processed guitar-14.gif → /Users/hyang/Desktop/original/processed/guitar-14.gif
# Processed device2-1.gif → /Users/hyang/Desktop/original/processed/device2-1.gif
# Processed bottle-13.gif → /Users/hyang/Desktop/original/processed/bottle-13.gif
# Processed spring-8.gif → /Users/hyang/Desktop/original/processed/spring-8.gif
# Processed bottle-07.gif → /Users/hyang/Desktop/original/processed/bottle-07.gif
# Processed ray-9.gif → /Users/hyang/Desktop/original/processed/ray-9.gif
# Processed fountain-13.gif → /Users/hyang/Desktop/original/processed/fountain-13.gif
# Processed fountain-07.gif → /Users/hyang/Desktop/original/processed/fountain-07.gif
# Processed fountain-06.gif → /Users/hyang/Desktop/original/processed/fountain-06.gif
# Processed fountain-12.gif → /Users/hyang/Desktop/original/processed/fountain-12.gif
# Processed ray-8.gif → /Users/hyang/Desktop/original/processed/ray-8.gif
# Processed bottle-06.gif → /Users/hyang/Desktop/original/processed/bottle-06.gif
# Processed Bone-1.gif → /Users/hyang/Desktop/original/processed/Bone-1.gif
# Processed spring-9.gif → /Users/hyang/Desktop/original/processed/spring-9.gif
# Processed bottle-12.gif → /Users/hyang/Desktop/original/processed/bottle-12.gif
# Processed beetle-1.gif → /Users/hyang/Desktop/original/processed/beetle-1.gif
# Processed guitar-15.gif → /Users/hyang/Desktop/original/processed/guitar-15.gif
# Processed guitar-9.gif → /Users/hyang/Desktop/original/processed/guitar-9.gif
# Processed personal_car-6.gif → /Users/hyang/Desktop/original/processed/personal_car-6.gif
# Processed Glas-17.gif → /Users/hyang/Desktop/original/processed/Glas-17.gif
# Processed pocket-9.gif → /Users/hyang/Desktop/original/processed/pocket-9.gif
# Processed device2-12.gif → /Users/hyang/Desktop/original/processed/device2-12.gif
# Processed fish-6.gif → /Users/hyang/Desktop/original/processed/fish-6.gif
# Processed tree-19.gif → /Users/hyang/Desktop/original/processed/tree-19.gif
# Processed dog-9.gif → /Users/hyang/Desktop/original/processed/dog-9.gif
# Processed hammer-14.gif → /Users/hyang/Desktop/original/processed/hammer-14.gif
# Processed brick-06.gif → /Users/hyang/Desktop/original/processed/brick-06.gif
# Processed brick-12.gif → /Users/hyang/Desktop/original/processed/brick-12.gif
# Processed device0-2.gif → /Users/hyang/Desktop/original/processed/device0-2.gif
# Processed sea_snake-14.gif → /Users/hyang/Desktop/original/processed/sea_snake-14.gif
# Processed spoon-8.gif → /Users/hyang/Desktop/original/processed/spoon-8.gif
# Processed crown-12.gif → /Users/hyang/Desktop/original/processed/crown-12.gif
# Processed rat-10.gif → /Users/hyang/Desktop/original/processed/rat-10.gif
# Processed bird-13.gif → /Users/hyang/Desktop/original/processed/bird-13.gif
# Processed rat-04.gif → /Users/hyang/Desktop/original/processed/rat-04.gif
# Processed device0-17.gif → /Users/hyang/Desktop/original/processed/device0-17.gif
# Processed jar-10.gif → /Users/hyang/Desktop/original/processed/jar-10.gif
# Processed Misk-13.gif → /Users/hyang/Desktop/original/processed/Misk-13.gif
# Processed Heart-3.gif → /Users/hyang/Desktop/original/processed/Heart-3.gif
# Processed shoe-10.gif → /Users/hyang/Desktop/original/processed/shoe-10.gif
# Processed octopus-10.gif → /Users/hyang/Desktop/original/processed/octopus-10.gif
# Processed camel-16.gif → /Users/hyang/Desktop/original/processed/camel-16.gif
# Processed elephant-1.gif → /Users/hyang/Desktop/original/processed/elephant-1.gif
# Processed device6-4.gif → /Users/hyang/Desktop/original/processed/device6-4.gif
# Processed deer-13.gif → /Users/hyang/Desktop/original/processed/deer-13.gif
# Processed teddy-11.gif → /Users/hyang/Desktop/original/processed/teddy-11.gif
# Processed teddy-05.gif → /Users/hyang/Desktop/original/processed/teddy-05.gif
# Processed deer-3.gif → /Users/hyang/Desktop/original/processed/deer-3.gif
# Processed key-11.gif → /Users/hyang/Desktop/original/processed/key-11.gif
# Processed face-8.gif → /Users/hyang/Desktop/original/processed/face-8.gif
# Processed device4-6.gif → /Users/hyang/Desktop/original/processed/device4-6.gif
# Processed watch-4.gif → /Users/hyang/Desktop/original/processed/watch-4.gif
# Processed apple-8.gif → /Users/hyang/Desktop/original/processed/apple-8.gif
